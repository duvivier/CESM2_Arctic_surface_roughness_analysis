# %% [markdown]
# # Calculate seasonal vertical wind trends
#
# * **Description**: Reads in and creates cross section plots of wind trends
# * **Input data**: CESM2-LE and Rufmod output in timeseries format
# * **Output data**: PNG figures of trends
# * **Creator**: Alice DuVivier
# * **Date**: March 2022

# %% [markdown]
# The rufmod experiments were performed where the sea ice roughness over Arctic sea ice regions was set to be equal to what it would be over open ocean. This is to better understand ice-atmosphere coupling, processes, and feedbacks.

# %%
import xarray as xr
import numpy as np
from datetime import timedelta
import glob

import pop_tools

import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.gridspec import GridSpec

import geocat.datafiles as gdf
import geocat.viz.util as gvutil
from geocat.viz import cmaps as gvcmaps
import geocat.comp as gcomp

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from scipy.stats import linregress,pearsonr, t

import dask
import intake
from distributed import Client
from ncar_jobqueue import NCARCluster
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
# spin up dask cluster

import dask

# Use dask jobqueue
from dask_jobqueue import PBSCluster

# Import a client
from dask.distributed import Client

# Setup your PBSCluster
cluster = PBSCluster(
    cores=2, # The number of cores you want
    memory='32 GB', # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    #resource_spec='select=1:ncpus=2:mem=256GB', # Specify resources
    project='P93300665', # Input your project ID here
    walltime='04:00:00', # Amount of wall time
    interface='ib0', # Interface to use
)
# Scale up
cluster.scale(32)

# Change your url to the dask dashboard so you can see it
dask.config.set({'distributed.dashboard.link':'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'})

# Setup your client
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.12.206.18:43033' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Manually set variables

# %%
# list the variables to load
var_in_1 = 'U'
var_in_2 = 'V'
var_in_3 = 'PS'

# %% [markdown]
# ## Load rufmod experiments

# %%
# Load "rufmod" data
#choose cases and data paths
case1 = 'b.e21.BSSP370.f09_g17.rufmod.001'
case2 = 'b.e21.BSSP370.f09_g17.rufmod.002'
case3 = 'b.e21.BSSP370.f09_g17.rufmod.003'
case4 = 'b.e21.BSSP370.f09_g17.rufmod.004'
case5 = 'b.e21.BSSP370.f09_g17.rufmod.005'

# set base directory where all data live
data_dir = '/glade/campaign/cesm/development/pcwg/duvivier/arctic_cyclones/'
# set individual data directories
data_dir1 = data_dir+case1+'/atm/proc/tseries/month_1/'
data_dir2 = data_dir+case2+'/atm/proc/tseries/month_1/'
data_dir3 = data_dir+case3+'/atm/proc/tseries/month_1/'
data_dir4 = data_dir+case4+'/atm/proc/tseries/month_1/'
data_dir5 = data_dir+case5+'/atm/proc/tseries/month_1/'

# %%
# %%time
#reading in files
print("loading "+var_in_1)   
ds1_1 = []
ds2_1 = []
ds3_1 = []
ds4_1 = []
ds5_1 = []
my_files=sorted(glob.glob(data_dir1+case1+'.cam.h0.'+var_in_1+'.*.nc'))
ds1_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir2+case2+'.cam.h0.'+var_in_1+'.*.nc'))
ds2_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir3+case3+'.cam.h0.'+var_in_1+'.*.nc'))
ds3_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')    
my_files=sorted(glob.glob(data_dir4+case4+'.cam.h0.'+var_in_1+'.*.nc'))
ds4_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir5+case5+'.cam.h0.'+var_in_1+'.*.nc'))
ds5_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')

print("loading "+var_in_2)   
ds1_2 = []
ds2_2 = []
ds3_2 = []
ds4_2 = []
ds5_2 = []
my_files=sorted(glob.glob(data_dir1+case1+'.cam.h0.'+var_in_2+'.*.nc'))
ds1_2=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir2+case2+'.cam.h0.'+var_in_2+'.*.nc'))
ds2_2=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir3+case3+'.cam.h0.'+var_in_2+'.*.nc'))
ds3_2=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')    
my_files=sorted(glob.glob(data_dir4+case4+'.cam.h0.'+var_in_2+'.*.nc'))
ds4_2=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir5+case5+'.cam.h0.'+var_in_2+'.*.nc'))
ds5_2=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')

print("loading "+var_in_3)   
ds1_3 = []
ds2_3 = []
ds3_3 = []
ds4_3 = []
ds5_3 = []
my_files=sorted(glob.glob(data_dir1+case1+'.cam.h0.'+var_in_3+'.*.nc'))
ds1_3=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir2+case2+'.cam.h0.'+var_in_3+'.*.nc'))
ds2_3=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir3+case3+'.cam.h0.'+var_in_3+'.*.nc'))
ds3_3=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')    
my_files=sorted(glob.glob(data_dir4+case4+'.cam.h0.'+var_in_3+'.*.nc'))
ds4_3=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir5+case5+'.cam.h0.'+var_in_3+'.*.nc'))
ds5_3=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
# Out:
# loading U
# loading V
# loading PS
# CPU times: user 1.32 s, sys: 338 ms, total: 1.66 s
# Wall time: 18.4 s

# %%
# concatenate them into a single array
futures_1 = xr.concat([ds1_1,ds2_1,ds3_1,ds4_1,ds5_1],dim='member_id')
futures_2 = xr.concat([ds1_2,ds2_2,ds3_2,ds4_2,ds5_2],dim='member_id')
futures_3 = xr.concat([ds1_3,ds2_3,ds3_3,ds4_3,ds5_3],dim='member_id')

# %%
# set member_id values
futures_1.member_id.values
futures_2.member_id.values
futures_3.member_id.values

# assign member_id as coordinate array
futures_1.assign_coords({"member_id": futures_1.member_id.values})
futures_2.assign_coords({"member_id": futures_2.member_id.values})
futures_3.assign_coords({"member_id": futures_3.member_id.values})
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, zlon: 1, member_id: 5, time: 1032, nbnd: 2, lon: 288, lev: 32, ilev: 33)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * zlon          (zlon) float64 0.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time          (time) object 2015-02-01 00:00:00 ... 2101-01-01 00:00:00
#   * member_id     (member_id) int64 0 1 2 3 4
# Dimensions without coordinates: nbnd
# Data variables: (12/27)
#     zlon_bnds     (member_id, time, zlon, nbnd) float64 dask.array<chunksize=(1, 600, 1, 2), meta=np.ndarray>
#     gw            (member_id, time, lat) float64 dask.array<chunksize=(1, 600, 192), meta=np.ndarray>
#     hyam          (member_id, time, lev) float64 dask.array<chunksize=(1, 600, 32), meta=np.ndarray>
#     hybm          (member_id, time, lev) float64 dask.array<chunksize=(1, 600, 32), meta=np.ndarray>
#     P0            (member_id, time) float64 1e+05 1e+05 1e+05 ... 1e+05 1e+05
#     hyai          (member_id, time, ilev) float64 dask.array<chunksize=(1, 600, 33), meta=np.ndarray>
#     ...            ...
#     n2ovmr        (member_id, time) float64 dask.array<chunksize=(1, 600), meta=np.ndarray>
#     f11vmr        (member_id, time) float64 dask.array<chunksize=(1, 600), meta=np.ndarray>
#     f12vmr        (member_id, time) float64 dask.array<chunksize=(1, 600), meta=np.ndarray>
#     sol_tsi       (member_id, time) float64 dask.array<chunksize=(1, 600), meta=np.ndarray>
#     nsteph        (member_id, time) float64 dask.array<chunksize=(1, 600), meta=np.ndarray>
#     PS            (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              b.e21.BSSP370.f09_g17.rufmod.001
#     logname:           duvivier
#     host:              cheyenne3
#     initial_file:      b.e21.BHIST.f09_g17.CMIP6-historical.rufmod.cam.i.2015...
#     topography_file:   /glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_0.9x1...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  month_1

# %%
# Shift months by one to be center of time period.
# Take average of the time bounds to get middle of month
# will lose some attributes with time, so may need to put this back in later...
futures_1['time'] = futures_1.time_bnds.load().mean(dim='nbnd').sel(member_id=0)
futures_2['time'] = futures_2.time_bnds.load().mean(dim='nbnd').sel(member_id=0)
futures_3['time'] = futures_3.time_bnds.load().mean(dim='nbnd').sel(member_id=0)

# %%
# get just NH slice
futures_1_masked = futures_1.isel(lat=slice(164,192))
futures_2_masked = futures_2.isel(lat=slice(164,192))
futures_3_masked = futures_3.isel(lat=slice(164,192))

# %%
# grab variables of interest
U_rufmod = futures_1_masked[var_in_1]
V_rufmod = futures_2_masked[var_in_2]
PS_rufmod = futures_3_masked[var_in_3]

# %%
# actually load data
U_rufmod.load()
V_rufmod.load()
PS_rufmod.load()
# Out:
# <xarray.DataArray 'PS' (member_id: 5, time: 1032, lat: 28, lon: 288)>
# array([[[[ 98824.69 ,  98853.04 ,  98889.445, ...,  98794.41 ,
#            98800.3  ,  98807.4  ],
#          [ 98790.01 ,  98808.42 ,  98835.12 , ...,  98771.73 ,
#            98774.75 ,  98781.46 ],
#          [ 98774.77 ,  98781.445,  98799.03 , ...,  98777.29 ,
#            98773.266,  98773.96 ],
#          ...,
#          [ 99999.14 ,  99992.45 ,  99985.64 , ..., 100018.88 ,
#           100012.27 , 100005.73 ],
#          [ 99997.875,  99995.36 ,  99992.84 , ..., 100005.51 ,
#           100002.87 , 100000.33 ],
#          [100015.98 , 100015.98 , 100015.98 , ..., 100015.98 ,
#           100015.98 , 100015.98 ]],
#
#         [[ 98989.125,  98995.5  ,  99004.77 , ...,  98981.266,
#            98980.17 ,  98983.4  ],
#          [ 98958.36 ,  98953.92 ,  98954.35 , ...,  98990.3  ,
#            98975.47 ,  98964.836],
#          [ 98904.24 ,  98890.09 ,  98883.24 , ...,  98976.8  ,
#            98949.81 ,  98924.49 ],
# ...
#          [101269.78 , 101269.6  , 101269.555, ..., 101270.33 ,
#           101270.06 , 101269.9  ],
#          [101365.336, 101365.125, 101365.01 , ..., 101366.13 ,
#           101365.836, 101365.56 ],
#          [101464.13 , 101464.13 , 101464.13 , ..., 101464.13 ,
#           101464.13 , 101464.13 ]],
#
#         [[100734.16 , 100750.25 , 100769.   , ..., 100704.016,
#           100711.94 , 100724.28 ],
#          [100651.79 , 100668.79 , 100685.586, ..., 100616.79 ,
#           100626.76 , 100640.49 ],
#          [100571.57 , 100588.41 , 100604.66 , ..., 100531.62 ,
#           100541.69 , 100556.414],
#          ...,
#          [100758.2  , 100756.85 , 100755.53 , ..., 100762.555,
#           100760.93 , 100759.43 ],
#          [100776.98 , 100776.15 , 100775.38 , ..., 100779.695,
#           100778.72 , 100777.82 ],
#          [100798.45 , 100798.45 , 100798.45 , ..., 100798.45 ,
#           100798.45 , 100798.45 ]]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 64.55 65.5 66.44 67.38 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time     (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
# Dimensions without coordinates: member_id
# Attributes:
#     units:         Pa
#     long_name:     Surface pressure
#     cell_methods:  time: mean

# %%
# grab parameters for interpolation
hyam_rufmod = futures_1_masked["hyam"]
hybm_rufmod = futures_1_masked["hybm"]

# %%
# actually load data
hyam_rufmod.load()
hybm_rufmod.load()
# Out:
# <xarray.DataArray 'hybm' (member_id: 5, time: 1032, lev: 32)>
# array([[[0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ]],
#
#        [[0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
# ...
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ]],
#
#        [[0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ],
#         [0.        , 0.        , 0.        , ..., 0.95123053,
#          0.974336  , 0.9925561 ]]])
# Coordinates:
#   * lev      (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * time     (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
# Dimensions without coordinates: member_id
# Attributes:
#     long_name:  hybrid B coefficient at layer midpoints

# %% [markdown]
# ## Read the CESM-LE data
#
# We will use [`intake-esm`](https://intake-esm.readthedocs.io/en/latest/), which is a data catalog tool.
# It enables querying a database for the files we want, then loading those directly as an `xarray.Dataset`.
#
# First step is to set the "collection" for the CESM-LE, which depends on a json file conforming to the [ESM Catalog Specification](https://github.com/NCAR/esm-collection-spec).

# %%
catalog_file = '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'

cat = intake.open_esm_datastore(catalog_file)
# Out:
# /glade/work/duvivier/miniconda3/envs/analysis3/lib/python3.7/site-packages/intake_esm/core.py:84: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   self._df, self.catalog_file = _fetch_catalog(self.esmcol_data, esmcol_obj, csv_kwargs)

# %%
forcing = 'cmip6'  # do not want smbb data
expt = 'ssp370'
comp = 'atm'
freq = 'month_1'

subset_1 = cat.search(variable=var_in_1, forcing_variant=forcing, experiment=expt, component=comp, frequency=freq )
subset_2 = cat.search(variable=var_in_2, forcing_variant=forcing, experiment=expt, component=comp, frequency=freq )
subset_3 = cat.search(variable=var_in_3, forcing_variant=forcing, experiment=expt, component=comp, frequency=freq )

# %%
subset_1
# Out:
# <p><strong>glade-cesm2-le catalog with 1 dataset(s) from 450 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>case</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>450</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>cesm_member_id</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>control_branch_year</th>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>cmip_experiment_id</th>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
subset_1.df.head()
# Out:
#   component  stream                                     case    member_id  \
# 0       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 1       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 2       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 3       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 4       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
#
#   variable start_time end_time     time_range   long_name units  \
# 0        U    2015-01  2024-12  201501-202412  Zonal wind   m/s
# 1        U    2025-01  2034-12  202501-203412  Zonal wind   m/s
# 2        U    2035-01  2044-12  203501-204412  Zonal wind   m/s
# 3        U    2045-01  2054-12  204501-205412  Zonal wind   m/s
# 4        U    2055-01  2064-12  205501-206412  Zonal wind   m/s
#
#    vertical_levels frequency  \
# 0              1.0   month_1
# 1              1.0   month_1
# 2              1.0   month_1
# 3              1.0   month_1
# 4              1.0   month_1
#
#                                                 path experiment  \
# 0  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/a...     ssp370
# 1  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/a...     ssp370
# 2  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/a...     ssp370
# 3  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/a...     ssp370
# 4  /glade/campaign/cgd/cesm/CESM2-LE/timeseries/a...     ssp370
#
#   forcing_variant  cesm_member_id  control_branch_year  \
# 0           cmip6        1001.001                 1001
# 1           cmip6        1001.001                 1001
# 2           cmip6        1001.001                 1001
# 3           cmip6        1001.001                 1001
# 4           cmip6        1001.001                 1001
#
#          cmip_experiment_id
# 0  CESM2_ssp370_r1i1001p1f1
# 1  CESM2_ssp370_r1i1001p1f1
# 2  CESM2_ssp370_r1i1001p1f1
# 3  CESM2_ssp370_r1i1001p1f1
# 4  CESM2_ssp370_r1i1001p1f1

# %%
# check that we only have cmip6, not smbb, data
member_id = list(subset_1.df.experiment.unique())
print(member_id)
# Out:
# ['ssp370']

# %%
# %%time
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets_1 = subset_1.to_dataset_dict(cdf_kwargs={'chunks': {'time':240}, 'decode_times': True})
    
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets_2 = subset_2.to_dataset_dict(cdf_kwargs={'chunks': {'time':240}, 'decode_times': True})
    
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets_3 = subset_3.to_dataset_dict(cdf_kwargs={'chunks': {'time':240}, 'decode_times': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# CPU times: user 21.5 s, sys: 278 ms, total: 21.8 s
# Wall time: 26.2 s

# %%
# load in the future datasets
futures_1 = []
for key in sorted(dsets_1.keys()):
    futures_1.append(dsets_1[key])
    print(key)

futures_2 = []
for key in sorted(dsets_2.keys()):
    futures_2.append(dsets_2[key])
    print(key)
    
futures_3 = []
for key in sorted(dsets_3.keys()):
    futures_3.append(dsets_3[key])
    print(key)
# Out:
# atm.ssp370.cam.h0.cmip6.U
# atm.ssp370.cam.h0.cmip6.V
# atm.ssp370.cam.h0.cmip6.PS

# %%
future_ds_1 = xr.concat(futures_1, dim='member_id')
future_ds_2 = xr.concat(futures_2, dim='member_id')
future_ds_3 = xr.concat(futures_3, dim='member_id')

# %%
future_ds_1.time
# Out:
# <xarray.DataArray 'time' (time: 1032)>
# array([cftime.DatetimeNoLeap(2015, 2, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 3, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 4, 1, 0, 0, 0, 0, has_year_zero=True), ...,
#        cftime.DatetimeNoLeap(2100, 11, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 12, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2101, 1, 1, 0, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2015-02-01 00:00:00 ... 2101-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds

# %%
# Shift months by one to be center of time period.
# Take average of the time bounds to get middle of month
# will lose some attributes with time, so may need to put this back in later...
future_ds_1['time'] = future_ds_1.time_bnds.load().mean(dim='nbnd').sel(member_id='r1i1281p1f1')
future_ds_2['time'] = future_ds_2.time_bnds.load().mean(dim='nbnd').sel(member_id='r1i1281p1f1')
future_ds_3['time'] = future_ds_3.time_bnds.load().mean(dim='nbnd').sel(member_id='r1i1281p1f1')

# %%
# get just NH slice
future_ds_1_masked = future_ds_1.isel(lat=slice(164,192))
future_ds_2_masked = future_ds_2.isel(lat=slice(164,192))
future_ds_3_masked = future_ds_3.isel(lat=slice(164,192))

# %%
# grab variables of interest
U_le = future_ds_1_masked[var_in_1]
V_le = future_ds_2_masked[var_in_2]
PS_le = future_ds_3_masked[var_in_3]

# %%
# actually load data
U_le.load()
V_le.load()
PS_le.load()
# Out:
# distributed.scheduler - ERROR - Couldn't gather keys {"('getitem-70c66b0a352ae06959a0335384d383c8', 24, 2, 0, 0, 0)": ['tcp://10.12.206.59:41792'], "('getitem-70c66b0a352ae06959a0335384d383c8', 32, 5, 0, 0, 0)": ['tcp://10.12.206.59:45689'], "('getitem-70c66b0a352ae06959a0335384d383c8', 26, 7, 0, 0, 0)": ['tcp://10.12.206.42:36593'], "('getitem-70c66b0a352ae06959a0335384d383c8', 16, 4, 0, 0, 0)": ['tcp://10.12.206.59:38474'], "('getitem-70c66b0a352ae06959a0335384d383c8', 49, 8, 0, 0, 0)": ['tcp://10.12.206.42:36252'], "('getitem-70c66b0a352ae06959a0335384d383c8', 21, 4, 0, 0, 0)": ['tcp://10.12.206.59:33469'], "('getitem-70c66b0a352ae06959a0335384d383c8', 34, 0, 0, 0, 0)": ['tcp://10.12.206.42:34554'], "('getitem-70c66b0a352ae06959a0335384d383c8', 39, 8, 0, 0, 0)": ['tcp://10.12.206.59:45168'], "('getitem-70c66b0a352ae06959a0335384d383c8', 5, 0, 0, 0, 0)": ['tcp://10.12.206.42:33276'], "('getitem-70c66b0a352ae06959a0335384d383c8', 17, 6, 0, 0, 0)": ['tcp://10.12.206.42:37877'], "('getitem-70c66b0a352ae06959a0335384d383c8', 48, 8, 0, 0, 0)": ['tcp://10.12.206.42:34190'], "('getitem-70c66b0a352ae06959a0335384d383c8', 38, 6, 0, 0, 0)": ['tcp://10.12.206.42:33276'], "('getitem-70c66b0a352ae06959a0335384d383c8', 8, 6, 0, 0, 0)": ['tcp://10.12.206.59:38474'], "('getitem-70c66b0a352ae06959a0335384d383c8', 42, 4, 0, 0, 0)": ['tcp://10.12.206.42:37877'], "('getitem-70c66b0a352ae06959a0335384d383c8', 20, 7, 0, 0, 0)": ['tcp://10.12.206.59:41792'], "('getitem-70c66b0a352ae06959a0335384d383c8', 17, 8, 0, 0, 0)": ['tcp://10.12.206.59:33469'], "('getitem-70c66b0a352ae06959a0335384d383c8', 9, 7, 0, 0, 0)": ['tcp://10.12.206.42:38077'], "('getitem-70c66b0a352ae06959a0335384d383c8', 11, 3, 0, 0, 0)": ['tcp://10.12.206.42:33276'], "('getitem-70c66b0a352ae06959a0335384d383c8', 49, 3, 0, 0, 0)": ['tcp://10.12.206.55:44195'], "('getitem-70c66b0a352ae06959a0335384d383c8', 12, 0, 0, 0, 0)": ['tcp://10.12.206.42:37877'], "('getitem-70c66b0a352ae06959a0335384d383c8', 14, 4, 0, 0, 0)": ['tcp://10.12.206.59:45168'], "('getitem-70c66b0a352ae06959a0335384d383c8', 31, 5, 0, 0, 0)": ['tcp://10.12.206.59:37826'], "('getitem-70c66b0a352ae06959a0335384d383c8', 6, 5, 0, 0, 0)": ['tcp://10.12.206.55:44195'], "('getitem-70c66b0a352ae06959a0335384d383c8', 13, 7, 0, 0, 0)": ['tcp://10.12.206.59:39673'], "('getitem-70c66b0a352ae06959a0335384d383c8', 1, 2, 0, 0, 0)": ['tcp://10.12.206.59:33469'], "('getitem-70c66b0a352ae06959a0335384d383c8', 43, 0, 0, 0, 0)": ['tcp://10.12.206.55:43077'], "('getitem-70c66b0a352ae06959a0335384d383c8', 21, 7, 0, 0, 0)": ['tcp://10.12.206.42:38077'], "('getitem-70c66b0a352ae06959a0335384d383c8', 25, 4, 0, 0, 0)": ['tcp://10.12.206.42:37877'], "('getitem-70c66b0a352ae06959a0335384d383c8', 12, 7, 0, 0, 0)": ['tcp://10.12.206.42:37877'], "('getitem-70c66b0a352ae06959a0335384d383c8', 10, 6, 0, 0, 0)": ['tcp://10.12.206.42:36593'], "('getitem-70c66b0a352ae06959a0335384d383c8', 34, 1, 0, 0, 0)": ['tcp://10.12.206.55:46503'], "('getitem-70c66b0a352ae06959a0335384d383c8', 1, 1, 0, 0, 0)": ['tcp://10.12.206.55:44195'], "('getitem-70c66b0a352ae06959a0335384d383c8', 38, 3, 0, 0, 0)": ['tcp://10.12.206.59:39846'], "('getitem-70c66b0a352ae06959a0335384d383c8', 38, 5, 0, 0, 0)": ['tcp://10.12.206.59:37801'], "('getitem-70c66b0a352ae06959a0335384d383c8', 23, 1, 0, 0, 0)": ['tcp://10.12.206.59:38474'], "('getitem-70c66b0a352ae06959a0335384d383c8', 4, 4, 0, 0, 0)": ['tcp://10.12.206.59:44962'], "('getitem-70c66b0a352ae06959a0335384d383c8', 35, 2, 0, 0, 0)": ['tcp://10.12.206.59:46489'], "('getitem-70c66b0a352ae06959a0335384d383c8', 48, 4, 0, 0, 0)": ['tcp://10.12.206.59:44962'], "('getitem-70c66b0a352ae06959a0335384d383c8', 44, 7, 0, 0, 0)": ['tcp://10.12.206.59:38474'], "('getitem-70c66b0a352ae06959a0335384d383c8', 40, 3, 0, 0, 0)": ['tcp://10.12.206.59:46489'], "('getitem-70c66b0a352ae06959a0335384d383c8', 5, 4, 0, 0, 0)": ['tcp://10.12.206.59:46378'], "('getitem-70c66b0a352ae06959a0335384d383c8', 0, 0, 0, 0, 0)": ['tcp://10.12.206.59:39846'], "('geti ...
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 34, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 17, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 20, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 17, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 34, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 34, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 30, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 30, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 34, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 34, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 17, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 20, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 46, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 46, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 40, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 29, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39831'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 29, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 38, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 29, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 46, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 29, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:43077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 30, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46378'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 0, 0, 0, 0)
# NoneType: None
# ...
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 5, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:33469'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 39, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 11, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 1, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 23, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 42, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 14, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:44195'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 31, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:41792'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 35, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 0, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 13, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 21, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36593'], ('getitem-70c66b0a352ae06959a0335384d383c8', 7, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 48, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34190'], ('getitem-70c66b0a352ae06959a0335384d383c8', 41, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 49, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 30, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 28, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 25, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 12, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:41381'], ('getitem-70c66b0a352ae06959a0335384d383c8', 27, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 26, 1, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 32, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 10, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:46503'], ('getitem-70c66b0a352ae06959a0335384d383c8', 37, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 17, 4, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37877'], ('getitem-70c66b0a352ae06959a0335384d383c8', 19, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:37412'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:33276'], ('getitem-70c66b0a352ae06959a0335384d383c8', 8, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:34554'], ('getitem-70c66b0a352ae06959a0335384d383c8', 47, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 36, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45689'], ('getitem-70c66b0a352ae06959a0335384d383c8', 43, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 16, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 22, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37801'], ('getitem-70c66b0a352ae06959a0335384d383c8', 9, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:37826'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:44962'], ('getitem-70c66b0a352ae06959a0335384d383c8', 33, 3, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 17, 2, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 44, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:38474'], ('getitem-70c66b0a352ae06959a0335384d383c8', 30, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:45168'], ('getitem-70c66b0a352ae06959a0335384d383c8', 4, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:36252'], ('getitem-70c66b0a352ae06959a0335384d383c8', 24, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39846'], ('getitem-70c66b0a352ae06959a0335384d383c8', 3, 8, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.55:41070'], ('getitem-70c66b0a352ae06959a0335384d383c8', 18, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 29, 5, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:39382'], ('getitem-70c66b0a352ae06959a0335384d383c8', 45, 0, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:46489'], ('getitem-70c66b0a352ae06959a0335384d383c8', 2, 7, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.59:39673'], ('getitem-70c66b0a352ae06959a0335384d383c8', 15, 6, 0, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://10.12.206.42:38077'], ('getitem-70c66b0a352ae06959a0335384d383c8', 6, 0, 0, 0, 0)
# NoneType: None

# %%
# grab parameters for interpolation
hyam_rufmod = futures_1_masked["hyam"]
hybm_rufmod = futures_1_masked["hybm"]

# %%
# actually load data
hyam_rufmod.load()
hybm_rufmod.load()

# %%
# Keep just variables of interest and calculate wind speed
WS_le = np.sqrt(future_ds_1_masked[var_in_1]**2 + future_ds_2_masked[var_in_2]**2)
PS_le = future_ds_3_masked[var_in_3]

# %%
# grab parameters for interpolation
hyam_le = future_ds_1_masked["hyam"]
hybm_le = future_ds_1_masked["hybm"]

# %%
# actually load data
WS_le.persist()
PS_le.persist()
hyam_le.persist()
hybm_le.persist()

# %% [markdown]
# ## Calculate scalar wind speed

# %%
# Keep just variables of interest and calculate wind speed
WS_rufmod = np.sqrt(futures_1_masked[var_in_1]**2 + futures_2_masked[var_in_2]**2)
PS_rufmod = futures_3_masked[var_in_3]

# %% [markdown]
# ## Mask data

# %%
# Load a Landfrac mask
ds_masks = xr.open_mfdataset('/glade/p/cgd/ppc/duvivier/masks/b.e21.BSSP370.f09_g17.rufmod.001.cam.h0.2015-01.nc')
my_mask = ds_masks['LANDFRAC'].isel(time=0)

# %%
my_mask = my_mask.isel(lat=slice(164,192))

# %%
# set mask lat/lon to equal those from LE, otherwise masking below doesn't work properly
my_mask['lat'] = PS_le['lat']
my_mask['lon'] = PS_le['lon']

# do same for the rufmod experiments
WS_rufmod['lat'] = PS_le['lat']
WS_rufmod['lon'] = PS_le['lon']
PS_rufmod['lat'] = PS_le['lat']
PS_rufmod['lon'] = PS_le['lon']

# %%
# Keep just ocean points
PS_le = PS_le.where(my_mask<0.5)
WS_le = WS_le.where(my_mask<0.5)

PS_rufmod = PS_rufmod.where(my_mask<0.5)
WS_rufmod = WS_rufmod.where(my_mask<0.5)

# %%
WS_le.persist()
PS_le.persist()
hyam_le.persist()
hybm_le.persist()

WS_rufmod.persist()
PS_rufmod.persist()
hyam_rufmod.persist()
hybm_rufmod.persist()

# %% [markdown]
# ## Interpolate to new pressure levels from hybrid levels

# %%
# set a surface reference pressure [Pa]
p0 = 100000

# %%
# Specify output pressure levels
new_levels = np.array([1000, 975, 950, 925, 900, 875, 850, 825, 800, 775, 750, 700, 600, 500, 400, 300, 200])  # in millibars
new_levels = new_levels * 100  # convert to Pascals

# %%
# interpolate le to the new levels

# CESM2-LE
WS_le_interp = gcomp.interp_hybrid_to_pressure(WS_le,
                                               PS_le,
                                               hyam_le, hybm_le, p0 = p0,
                                               new_levels=new_levels,
                                               method='linear')
# SMOOTH
WS_rufmod_interp = gcomp.interp_hybrid_to_pressure(WS_rufmod,
                                                   PS_rufmod,
                                                   hyam_rufmod, hybm_rufmod, p0 = p0,
                                                   new_levels=new_levels,
                                                   method='linear')

# %%
WS_le_interp

# %%
# actually load data
WS_le_interp.load()
WS_rufmod_interp.load()

# %%
# actually load data
#WS_le.load()
#PS_le.load()
#hyam_le.load()
#hybm_le.load()

#WS_rufmod.load()
#PS_rufmod.load()
#hyam_rufmod.load()
#hybm_rufmod.load()

# %% [markdown]
# ## Calculate seasonal means

# %%
season_names = ['OND','JFM', 'AMJ', 'JAS']

# %%
# find total years
xarr_le = WS_zonal_le.coords['time.year'][(WS_zonal_le.coords['time.month']==1)]
xarr_rufmod = WS_zonal_rufmod.coords['time.year'][(WS_zonal_rufmod.coords['time.month']==1)]

# %%
# Loop through seasons - rufmod

# make numpy array to fill and specify dimensions we want
seas_array_rufmod = np.zeros([len(season_names),len(xarr_rufmod),len(WS_zonal_rufmod.member_id),len(WS_zonal_rufmod.lev),len(WS_zonal_rufmod.lat)])

for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # get temporary array of just these month by season
    if ss == 'JFM':
        temp1 = WS_zonal_rufmod.isel(time=WS_zonal_rufmod.time.dt.month.isin([1,2,3]))
    if ss == 'AMJ':
        temp1 = WS_zonal_rufmod.isel(time=WS_zonal_rufmod.time.dt.month.isin([4,5,6]))
    if ss == 'JAS':
        temp1 = WS_zonal_rufmod.isel(time=WS_zonal_rufmod.time.dt.month.isin([7,8,9]))
    if ss == 'OND':
        temp1 = WS_zonal_rufmod.isel(time=WS_zonal_rufmod.time.dt.month.isin([10,11,12]))
    # now loop through years to get the seasonal average by year for each ensemble member
    for yy in xarr_rufmod:
        if yy == 2015:
            y_count = 0
        else: 
            y_count = y_count+1 
        # select only the indexes for this year
        temp2 = temp1.isel(time=temp1.time.dt.year.isin([yy]))
        temp3 = temp2.mean(dim='time')
        seas_array_rufmod[s_count,y_count,:,:,:] = temp3

# %%
# Loop through seasons - CESM2-LE

# make numpy array to fill and specify dimensions we want
seas_array_le = np.zeros([len(season_names),len(xarr_le),len(WS_zonal_le.member_id),len(WS_zonal_le.lev),len(WS_zonal_le.lat)])

for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # get temporary array of just these month by season
    if ss == 'JFM':
        temp1 = WS_zonal_le.isel(time=WS_zonal_le.time.dt.month.isin([1,2,3]))
    if ss == 'AMJ':
        temp1 = WS_zonal_le.isel(time=WS_zonal_le.time.dt.month.isin([4,5,6]))
    if ss == 'JAS':
        temp1 = WS_zonal_le.isel(time=WS_zonal_le.time.dt.month.isin([7,8,9]))
    if ss == 'OND':
        temp1 = WS_zonal_le.isel(time=WS_zonal_le.time.dt.month.isin([10,11,12]))
    # now loop through years to get the seasonal average by year for each ensemble member
    for yy in xarr_le:
        if yy == 2015:
            y_count = 0
        else: 
            y_count = y_count+1 
        # select only the indexes for this year
        temp2 = temp1.isel(time=temp1.time.dt.year.isin([yy]))
        temp3 = temp2.mean(dim='time')
        seas_array_le[s_count,y_count,:,:,:] = temp3

# %%
print(seas_array_le.shape)
print(seas_array_rufmod.shape)

# %%
# convert the numpy array to a xarray for easier plotting
WS_zonal_seas_le = xr.DataArray(seas_array_le,dims=('season','time','member_id','lev','lat'))
WS_zonal_seas_rufmod = xr.DataArray(seas_array_rufmod,dims=('season','time','member_id','lev','lat'))

# %%
# set coordinate arrays
WS_zonal_seas_le['season'] = season_names
WS_zonal_seas_le['time'] = xarr_le
WS_zonal_seas_le['member_id'] = WS_zonal_le['member_id']
WS_zonal_seas_le['lat'] = WS_zonal_le['lat'].values
WS_zonal_seas_le['lev'] = WS_zonal_le['lev'].values

WS_zonal_seas_rufmod['season'] = season_names
WS_zonal_seas_rufmod['time'] = xarr_rufmod
WS_zonal_seas_rufmod['member_id'] = WS_zonal_rufmod['member_id']
WS_zonal_seas_rufmod['lat'] = WS_zonal_rufmod['lat'].values
WS_zonal_seas_rufmod['lev'] = WS_zonal_rufmod['lev'].values

# %% [markdown]
# ## Calculate ensemble mean

# %%
# Calculate ensemble means
WS_zonal_seas_ens_mean_le = WS_zonal_seas_le.mean(dim='member_id')
WS_zonal_seas_ens_mean_rufmod = WS_zonal_seas_rufmod.mean(dim='member_id')

# %%
WS_zonal_seas_ens_mean_le

# %% [markdown]
# ## Calculate Linear trends

# %%
# define some functions from Liz Maroon
# These allow us to do a linear regression at all points

def pvalue_array(x,y,dname):
    x_an=x-x.mean(dname)
    slope=((x_an)*(y-y.mean(dname))).sum(dname)/((x_an)*(x_an)).sum(dname)
    interc=y.mean(dname)-slope*x.mean(dname)
    ypred=slope*x+interc  
    n=len(x[dname])
    mse=np.sqrt(((y-ypred)**2).sum(dname)/(n-2))
    xsq=np.sqrt(((x_an)**2).sum(dname))
    standerr=mse/xsq
    pval=2*(1-t.cdf(np.abs(slope/standerr),n-2))
    pval=xr.DataArray(pval,dims=standerr.dims,coords=standerr.coords)
    return pval

def rvalue_array(x,y,dname):  
    xmean=x.mean(dname)
    ymean=y.mean(dname)
    numer=(x*y).mean(dname)-xmean*ymean
    denom=np.sqrt(((x**2).mean(dname)-xmean**2)*\
                  (((y**2).mean(dname))-(ymean**2)))
    return numer/denom

def regcoeff_array(x,y,dname):
    x_an=x-x.mean(dname)
    y_an=y-y.mean(dname)
    slope=(x_an*y_an).sum(dname)/(x_an*x_an).sum(dname)
    return slope

# %%
# test this with Liz's functions
tseries = xarr_rufmod
# grab first season only
spatial = WS_zonal_seas_ens_mean_rufmod[0,:,:,:]
# set time coordinate arrays to be equal
tseries['time'] = spatial.time
# calculate stats
regcoeff=regcoeff_array(tseries,spatial,'time')
rvalues=rvalue_array(tseries,spatial,'time')
pvalues=pvalue_array(tseries,spatial,'time')
# plot return
regcoeff.plot()

# %%
WS_zonal_seas_ens_mean_rufmod.time

# %%
# Loop through the seasons to calculate regressions for full period
ind_st = 5
ind_ed = 85

# make numpy array to fill and specify dimensions we want
seas_array_rufmod = np.zeros([len(season_names),len(WS_zonal_rufmod.lev),len(WS_zonal_rufmod.lat)])
seas_array_le = np.zeros([len(season_names),len(WS_zonal_le.lev),len(WS_zonal_le.lat)])

for ss in season_names[0:1]:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # get data we want to regress
    tseries = xarr_le[ind_st:ind_ed]
    
    # select only the indexes for this year
    #    temp2 = temp1.isel(time=temp1.time.dt.year.isin([yy]))
    #    temp3 = temp2.mean(dim='time')
    #    seas_array_rufmod[s_count,y_count,:,:,:] = temp3

# %%
tseries

# %%
WS_zonal_seas_ens_mean_le

# %%
    # grab data we want to regress
    tseries = xarr_le[ind_st:ind_ed]
    spatial_le = U10_seas_ens_mean_le[count,ind_st:ind_ed,:,:]
    spatial_rufmod = U10_seas_ens_mean_rufmod[count,ind_st:ind_ed,:,:]
    # set time coordinate arrays to be equal
    spatial_rufmod['time'] = spatial_le.time
    tseries['time'] = spatial_le.time

    # Calculate CESM2-LE regressions (and convert to by decade)
    regcoeff_le=10*regcoeff_array(tseries,spatial_le,'time')
    rvalues_le=rvalue_array(tseries,spatial_le,'time')
    pvalues_le=pvalue_array(tseries,spatial_le,'time')
    regcoeff_le_masked = regcoeff_le.where(pvalues_le < sigval)

    # Calculate rufmod regressions
    regcoeff_rufmod=10*regcoeff_array(tseries,spatial_rufmod,'time')
    rvalues_rufmod=rvalue_array(tseries,spatial_rufmod,'time')
    pvalues_rufmod=pvalue_array(tseries,spatial_rufmod,'time')
    regcoeff_rufmod_masked = regcoeff_rufmod.where(pvalues_rufmod < sigval)

# %%
# now calculate zonal means
WS_zonal_le = WS_le.mean(dim="lon")

# %%
WS_zonal_le

# %%
# Loop through the seasons to calculate regressions for full period
ind_st = 5
ind_ed = 85

# set units
units = '(m/s)'

# set significance level (0.05 --> 95%; 0.01 --> 99%)
sigval = 0.01

#Plot each season and percent difference
levels_in = np.arange(-0.2,0.25,0.05)
cmap_in = plt.cm.get_cmap('coolwarm')
levels_diff = np.arange(-70,80,10)
#levels_diff = np.arange(-100,110,10)
cmap_diff = plt.cm.get_cmap('bwr')

#for ss in season_names[0:1]:
for ss in season_names:
    print('Calculating regressions for '+ss)
    if ss == 'OND':
        count = 0
    else: 
        count = count+1
    #print(count)

    # grab data we want to regress
    tseries = xarr_le[ind_st:ind_ed]
    spatial_le = U10_seas_ens_mean_le[count,ind_st:ind_ed,:,:]
    spatial_rufmod = U10_seas_ens_mean_rufmod[count,ind_st:ind_ed,:,:]
    # set time coordinate arrays to be equal
    spatial_rufmod['time'] = spatial_le.time
    tseries['time'] = spatial_le.time

    # Calculate CESM2-LE regressions (and convert to by decade)
    regcoeff_le=10*regcoeff_array(tseries,spatial_le,'time')
    rvalues_le=rvalue_array(tseries,spatial_le,'time')
    pvalues_le=pvalue_array(tseries,spatial_le,'time')
    regcoeff_le_masked = regcoeff_le.where(pvalues_le < sigval)

    # Calculate rufmod regressions
    regcoeff_rufmod=10*regcoeff_array(tseries,spatial_rufmod,'time')
    rvalues_rufmod=rvalue_array(tseries,spatial_rufmod,'time')
    pvalues_rufmod=pvalue_array(tseries,spatial_rufmod,'time')
    regcoeff_rufmod_masked = regcoeff_rufmod.where(pvalues_rufmod < sigval)

    # calculate difference - need to also set coordinates to be equal
    regcoeff_rufmod_masked['lat'] = regcoeff_le_masked.lat.values
    regcoeff_rufmod_masked['lon'] = regcoeff_le_masked.lon.values
    diff = 100*((regcoeff_rufmod - regcoeff_le)/regcoeff_le)
    diff = 100*((regcoeff_rufmod_masked - regcoeff_le_masked)/regcoeff_le_masked)
        
    # add cyclic point
    regcoeff_le = gvutil.xr_add_cyclic_longitudes(regcoeff_le,"lon")
    regcoeff_le_masked = gvutil.xr_add_cyclic_longitudes(regcoeff_le_masked,"lon")
    regcoeff_rufmod = gvutil.xr_add_cyclic_longitudes(regcoeff_rufmod,"lon")    
    regcoeff_rufmod_masked = gvutil.xr_add_cyclic_longitudes(regcoeff_rufmod_masked,"lon")
    pvalues_le = gvutil.xr_add_cyclic_longitudes(pvalues_le,"lon")
    pvalues_rufmod = gvutil.xr_add_cyclic_longitudes(pvalues_rufmod,"lon") 
    diff = gvutil.xr_add_cyclic_longitudes(diff,"lon")
    
    # create figure
    fig = plt.figure(figsize=(20,20))
    fout = 'cesm2_le_and_rufmod_'+var_in_1+'_trends_2020_2100_'+ss
    title = ss+' U10 trend over sea ice - 2020-2100'
     
    # Make subplots - note it's nrow x ncol x index (starting upper left)
    # First subplot: CESM2-LE
    ax = fig.add_subplot(1,3,1, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(regcoeff_le.lon,regcoeff_le.lat,
                       regcoeff_le,
                       cmap=cmap_in,levels=levels_in,extend='both',
                       transform=ccrs.PlateCarree())
    # add contour lines and labels
    this2=ax.contour(regcoeff_le.lon,regcoeff_le.lat,
                       regcoeff_le,
                       colors='black',linestyles='solid',levels=levels_in,
                       transform=ccrs.PlateCarree())
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    # add significance overlay
    sig = ax.pcolor(pvalues_le.lon,pvalues_le.lat,
                       pvalues_le.where(pvalues_le > sigval),
                       alpha=0, hatch='xx',
                       transform=ccrs.PlateCarree())    
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel(units+'/decade', fontsize=15)
    plt.title('CESM2-LE',fontsize=20)

    # Second subplot: Rufmod aka SMOOTH
    ax = fig.add_subplot(1,3,2, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(regcoeff_rufmod.lon,regcoeff_rufmod.lat,
                       regcoeff_rufmod,
                       cmap=cmap_in,levels=levels_in,extend='both',
                       transform=ccrs.PlateCarree())
    # add contour lines and labels
    this2=ax.contour(regcoeff_rufmod.lon,regcoeff_rufmod.lat,
                       regcoeff_rufmod,
                       colors='black',linestyles='solid',levels=levels_in,
                       transform=ccrs.PlateCarree())
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    # add significance overlay
    sig = ax.pcolor(pvalues_rufmod.lon,pvalues_rufmod.lat,
                       pvalues_rufmod.where(pvalues_rufmod > sigval),
                       alpha=0, hatch='xx',
                       transform=ccrs.PlateCarree())    
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel(units+'/decade', fontsize=15)
    plt.title('SMOOTH',fontsize=20)
    
    # Third subplot: %difference
    ax = fig.add_subplot(1,3,3, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(diff.lon,diff.lat,
                       diff,
                       cmap=cmap_diff,levels=levels_diff,extend='both',
                       transform=ccrs.PlateCarree())
    # add contour lines and labels
    this2=ax.contour(diff.lon,diff.lat,
                       diff,
                       colors='black',linestyles='solid',levels=levels_diff,
                       transform=ccrs.PlateCarree())    
    plt.gca().clabel(this2,this2.levels[::2], inline=True, fontsize=10, colors='black') 
    #print(this2.levels[::2]) # or [3:14] or [2::2]
    
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel('% difference', fontsize=15)
    plt.title('% Difference from CESM2-LE',fontsize=20)
    
    # Finalize figure and save
    fig.suptitle(title,fontsize=15, y=0.75)  
    fig.subplots_adjust(bottom=0.45,wspace=0.1)
    #fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)

# %%
# Loop through the seasons to calculate regressions for full period
ind_st = 5
ind_ed = 85

# set units
units = '(m/s)'

# set significance level (0.05 --> 95%; 0.01 --> 99%)
sigval = 0.01

#Plot each season and percent difference
levels_in = np.arange(-0.2,0.25,0.05)
cmap_in = plt.cm.get_cmap('coolwarm')
levels_diff = np.arange(-70,80,10)
#levels_diff = np.arange(-100,110,10)
cmap_diff = plt.cm.get_cmap('bwr')

#for ss in season_names[0:1]:
for ss in season_names:
    print('Calculating regressions for '+ss)
    if ss == 'OND':
        count = 0
    else: 
        count = count+1
    #print(count)

    # grab data we want to regress
    tseries = xarr_le[ind_st:ind_ed]
    spatial_le = U10_seas_ens_mean_le[count,ind_st:ind_ed,:,:]
    spatial_rufmod = U10_seas_ens_mean_rufmod[count,ind_st:ind_ed,:,:]
    # set time coordinate arrays to be equal
    spatial_rufmod['time'] = spatial_le.time
    tseries['time'] = spatial_le.time

    # Calculate CESM2-LE regressions (and convert to by decade)
    regcoeff_le=10*regcoeff_array(tseries,spatial_le,'time')
    rvalues_le=rvalue_array(tseries,spatial_le,'time')
    pvalues_le=pvalue_array(tseries,spatial_le,'time')
    regcoeff_le_masked = regcoeff_le.where(pvalues_le < sigval)

    # Calculate rufmod regressions
    regcoeff_rufmod=10*regcoeff_array(tseries,spatial_rufmod,'time')
    rvalues_rufmod=rvalue_array(tseries,spatial_rufmod,'time')
    pvalues_rufmod=pvalue_array(tseries,spatial_rufmod,'time')
    regcoeff_rufmod_masked = regcoeff_rufmod.where(pvalues_rufmod < sigval)

    # calculate difference - need to also set coordinates to be equal
    regcoeff_rufmod_masked['lat'] = regcoeff_le_masked.lat.values
    regcoeff_rufmod_masked['lon'] = regcoeff_le_masked.lon.values
    diff = 100*((regcoeff_rufmod - regcoeff_le)/regcoeff_le)
    diff = 100*((regcoeff_rufmod_masked - regcoeff_le_masked)/regcoeff_le_masked)
        
    # add cyclic point
    regcoeff_le = gvutil.xr_add_cyclic_longitudes(regcoeff_le,"lon")
    regcoeff_le_masked = gvutil.xr_add_cyclic_longitudes(regcoeff_le_masked,"lon")
    regcoeff_rufmod = gvutil.xr_add_cyclic_longitudes(regcoeff_rufmod,"lon")    
    regcoeff_rufmod_masked = gvutil.xr_add_cyclic_longitudes(regcoeff_rufmod_masked,"lon")
    pvalues_le = gvutil.xr_add_cyclic_longitudes(pvalues_le,"lon")
    pvalues_rufmod = gvutil.xr_add_cyclic_longitudes(pvalues_rufmod,"lon") 
    diff = gvutil.xr_add_cyclic_longitudes(diff,"lon")
    
    # create figure
    fig = plt.figure(figsize=(20,20))
    fout = 'cesm2_le_and_rufmod_'+var_in_1+'_trends_2020_2100_'+ss
    title = ss+' U10 trend over sea ice - 2020-2100'
     
    # Make subplots - note it's nrow x ncol x index (starting upper left)
    # First subplot: CESM2-LE
    ax = fig.add_subplot(1,3,1, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(regcoeff_le.lon,regcoeff_le.lat,
                       regcoeff_le,
                       cmap=cmap_in,levels=levels_in,extend='both',
                       transform=ccrs.PlateCarree())
    # add significance overlay
    sig = ax.pcolor(pvalues_le.lon,pvalues_le.lat,
                       pvalues_le.where(pvalues_le > sigval),
                       alpha=0, hatch='xx',
                       transform=ccrs.PlateCarree())    
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel(units+'/decade', fontsize=15)
    plt.title('CESM2-LE',fontsize=20)

    # Second subplot: Rufmod aka SMOOTH
    ax = fig.add_subplot(1,3,2, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(regcoeff_rufmod.lon,regcoeff_rufmod.lat,
                       regcoeff_rufmod,
                       cmap=cmap_in,levels=levels_in,extend='both',
                       transform=ccrs.PlateCarree())
    # add significance overlay
    sig = ax.pcolor(pvalues_rufmod.lon,pvalues_rufmod.lat,
                       pvalues_rufmod.where(pvalues_rufmod > sigval),
                       alpha=0, hatch='xx',
                       transform=ccrs.PlateCarree())    
    plt.gca().clabel(this2,this2.levels, inline=True, fontsize=10, colors='black')
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel(units+'/decade', fontsize=15)
    plt.title('SMOOTH',fontsize=20)
    
    # Third subplot: %difference
    ax = fig.add_subplot(1,3,3, projection=ccrs.NorthPolarStereo())
    ax.add_feature(cfeature.LAND,zorder=100,edgecolor='k')
    ax.set_boundary(circle, transform=ax.transAxes)
    ax.set_extent([0.005, 360, 90, 65], crs=ccrs.PlateCarree())
    this=ax.contourf(diff.lon,diff.lat,
                       diff,
                       cmap=cmap_diff,levels=levels_diff,extend='both',
                       transform=ccrs.PlateCarree())
    cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04,pad=0.01)
    cbar.ax.tick_params(labelsize=15, labelrotation=45)
    cbar.ax.set_xlabel('% difference', fontsize=15)
    plt.title('% Difference from CESM2-LE',fontsize=20)
    
    # Finalize figure and save
    fig.suptitle(title,fontsize=15, y=0.75)  
    fig.subplots_adjust(bottom=0.45,wspace=0.1)
    fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
