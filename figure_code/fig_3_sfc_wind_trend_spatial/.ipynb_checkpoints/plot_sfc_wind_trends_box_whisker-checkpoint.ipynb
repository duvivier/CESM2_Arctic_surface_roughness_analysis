# %% [markdown]
# # Calculate seasonal wind trends at all Arctic points
#
# * **Description**: Reads in and creates spatial plots of wind trends
# * **Input data**: CESM2-LE and Rufmod output in timeseries format
# * **Output data**: PNG figures of trends
# * **Creator**: Alice DuVivier
# * **Date**: December 2021

# %% [markdown]
# The rufmod experiments were performed where the sea ice roughness over Arctic sea ice regions was set to be equal to what it would be over open ocean. This is to better understand ice-atmosphere coupling, processes, and feedbacks.

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.gridspec import GridSpec
import pop_tools
from datetime import timedelta
import glob
import geocat.datafiles as gdf
import geocat.viz.util as gvutil
from geocat.viz import cmaps as gvcmaps
import cartopy.crs as ccrs
import cartopy.feature as cfeature
#from scipy import stats
from scipy.stats import linregress,pearsonr, t

import dask
import intake
from distributed import Client
from ncar_jobqueue import NCARCluster

# %%
# spin up dask cluster

import dask

# Use dask jobqueue
from dask_jobqueue import PBSCluster

# Import a client
from dask.distributed import Client

# Setup your PBSCluster
cluster = PBSCluster(
    cores=2, # The number of cores you want
    memory='32 GB', # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    #resource_spec='select=1:ncpus=2:mem=256GB', # Specify resources
    project='P93300665', # Input your project ID here
    walltime='04:00:00', # Amount of wall time
    interface='ib0', # Interface to use
)
# Scale up
cluster.scale(32)

# Change your url to the dask dashboard so you can see it
dask.config.set({'distributed.dashboard.link':'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status'})

# Setup your client
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.12.206.63:45171' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Manually set variables

# %%
# list the variables to load
var_in_1 = 'U10'

# %%
# Load a Landfrac mask
ds_masks = xr.open_mfdataset('/glade/p/cgd/ppc/duvivier/masks/b.e21.BSSP370.f09_g17.rufmod.001.cam.h0.2015-01.nc')
my_mask = ds_masks['LANDFRAC'].isel(time=0)

# %% [markdown]
# ## Load rufmod experiments

# %%
# Load "rufmod" data
#choose cases and data paths
case1 = 'b.e21.BSSP370.f09_g17.rufmod.001'
case2 = 'b.e21.BSSP370.f09_g17.rufmod.002'
case3 = 'b.e21.BSSP370.f09_g17.rufmod.003'
case4 = 'b.e21.BSSP370.f09_g17.rufmod.004'
case5 = 'b.e21.BSSP370.f09_g17.rufmod.005'

# set base directory where all data live
data_dir = '/glade/campaign/cesm/development/pcwg/duvivier/arctic_cyclones/'
# set individual data directories
data_dir1 = data_dir+case1+'/atm/proc/tseries/month_1/'
data_dir2 = data_dir+case2+'/atm/proc/tseries/month_1/'
data_dir3 = data_dir+case3+'/atm/proc/tseries/month_1/'
data_dir4 = data_dir+case4+'/atm/proc/tseries/month_1/'
data_dir5 = data_dir+case5+'/atm/proc/tseries/month_1/'

# %%
# %%time
#reading in files
print("loading "+var_in_1)   
ds1_1 = []
ds2_1 = []
ds3_1 = []
ds4_1 = []
ds5_1 = []
my_files=sorted(glob.glob(data_dir1+case1+'.cam.h0.'+var_in_1+'.*.nc'))
ds1_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir2+case2+'.cam.h0.'+var_in_1+'.*.nc'))
ds2_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir3+case3+'.cam.h0.'+var_in_1+'.*.nc'))
ds3_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')    
my_files=sorted(glob.glob(data_dir4+case4+'.cam.h0.'+var_in_1+'.*.nc'))
ds4_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
my_files=sorted(glob.glob(data_dir5+case5+'.cam.h0.'+var_in_1+'.*.nc'))
ds5_1=xr.open_mfdataset(my_files,combine='by_coords',chunks={}, parallel=True, compat='override', coords='minimal')
# Out:
# loading U10
# CPU times: user 1.05 s, sys: 319 ms, total: 1.37 s
# Wall time: 31.9 s

# %%
# concatenate them into a single array
futures_1 = xr.concat([ds1_1,ds2_1,ds3_1,ds4_1,ds5_1],dim='member_id')

# %%
# set member_id values
futures_1.member_id.values

# assign member_id as coordinate array
futures_1.assign_coords({"member_id": futures_1.member_id.values})
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, zlon: 1, member_id: 5, time: 1032, nbnd: 2, lon: 288, lev: 32, ilev: 33)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * zlon          (zlon) float64 0.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time          (time) object 2015-02-01 00:00:00 ... 2101-01-01 00:00:00
#   * member_id     (member_id) int64 0 1 2 3 4
# Dimensions without coordinates: nbnd
# Data variables: (12/27)
#     zlon_bnds     (member_id, time, zlon, nbnd) float64 dask.array<chunksize=(1, 600, 1, 2), meta=np.ndarray>
#     gw            (member_id, time, lat) float64 dask.array<chunksize=(1, 600, 192), meta=np.ndarray>
# ...

# %%
futures_1
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, zlon: 1, member_id: 5, time: 1032, nbnd: 2, lon: 288, lev: 32, ilev: 33)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * zlon          (zlon) float64 0.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time          (time) object 2015-02-01 00:00:00 ... 2101-01-01 00:00:00
# Dimensions without coordinates: member_id, nbnd
# Data variables: (12/27)
#     zlon_bnds     (member_id, time, zlon, nbnd) float64 dask.array<chunksize=(1, 600, 1, 2), meta=np.ndarray>
#     gw            (member_id, time, lat) float64 dask.array<chunksize=(1, 600, 192), meta=np.ndarray>
#     hyam          (member_id, time, lev) float64 dask.array<chunksize=(1, 600, 32), meta=np.ndarray>
# ...

# %%
# Shift months by one to be center of time period.
# Take average of the time bounds to get middle of month
# will lose some attributes with time, so may need to put this back in later...
futures_1['time'] = futures_1.time_bnds.load().mean(dim='nbnd').sel(member_id=0)

# %%
futures_1.time
# Out:
# <xarray.DataArray 'time' (time: 1032)>
# array([cftime.DatetimeNoLeap(2015, 1, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 2, 15, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 3, 16, 12, 0, 0, 0, has_year_zero=True),
#        ...,
#        cftime.DatetimeNoLeap(2100, 10, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 12, 16, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00

# %%
U10_rufmod = futures_1[var_in_1]

# %%
U10_rufmod.sel(member_id=0).isel(time=0).plot()

# %%
#mask just NH ocean points
U10_masked_rufmod = U10_rufmod.where((U10_rufmod['lat']>70.0) & (my_mask<0.5), drop=True)

# %%
# test simple plot
U10_masked_rufmod.sel(member_id=0).isel(time=100).plot()

# %%
U10_masked_rufmod.load()
# Out:
# <xarray.DataArray 'U10' (member_id: 5, time: 1032, lat: 22, lon: 288)>
# array([[[[11.06793  , 10.969294 , 10.853632 , ..., 11.531877 ,
#           11.292971 , 11.175346 ],
#          [10.861583 , 10.791613 , 10.773669 , ..., 12.246518 ,
#           11.648091 , 11.174871 ],
#          [11.831094 , 11.298049 , 11.004476 , ..., 13.243856 ,
#           12.893343 , 12.308632 ],
#          ...,
#          [ 6.967016 ,  6.9751096,  6.980671 , ...,  6.9373527,
#            6.9472327,  6.9564366],
#          [ 6.7671547,  6.768988 ,  6.7709785, ...,  6.7615557,
#            6.762776 ,  6.764975 ],
#          [ 6.579826 ,  6.5804806,  6.581078 , ...,  6.57744  ,
#            6.578315 ,  6.579107 ]],
#
#         [[10.475566 , 10.284442 , 10.104487 , ..., 11.960213 ,
#           11.352178 , 10.809615 ],
#          [10.026171 ,  9.884076 ,  9.815837 , ..., 11.635889 ,
#           11.125332 , 10.501084 ],
#          [10.18181  ,  9.965411 ,  9.898421 , ..., 11.6331835,
# ...

# %% [markdown]
# ## Read the CESM-LE data
#
# We will use [`intake-esm`](https://intake-esm.readthedocs.io/en/latest/), which is a data catalog tool.
# It enables querying a database for the files we want, then loading those directly as an `xarray.Dataset`.
#
# First step is to set the "collection" for the CESM-LE, which depends on a json file conforming to the [ESM Catalog Specification](https://github.com/NCAR/esm-collection-spec).

# %%
catalog_file = '/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cesm2-le.json'

cat = intake.open_esm_datastore(catalog_file)
# Out:
# /glade/work/duvivier/miniconda3/envs/antarctica_som_env/lib/python3.7/site-packages/intake_esm/core.py:84: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   self._df, self.catalog_file = _fetch_catalog(self.esmcol_data, esmcol_obj, csv_kwargs)

# %%
forcing = 'cmip6'  # do not want smbb data
expt = 'ssp370'
comp = 'atm'
freq = 'month_1'

subset_1 = cat.search(variable=var_in_1, forcing_variant=forcing, experiment=expt, component=comp, frequency=freq )

# %%
subset_1
# Out:
# <p><strong>glade-cesm2-le catalog with 1 dataset(s) from 450 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>stream</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>case</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>9</td>
#     </tr>
#     <tr>
# ...

# %%
subset_1.df.head()
# Out:
#   component  stream                                     case    member_id  \
# 0       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 1       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 2       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 3       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
# 4       atm  cam.h0  b.e21.BSSP370cmip6.f09_g17.LE2-1001.001  r1i1001p1f1
#
#   variable start_time end_time     time_range       long_name units  \
# 0      U10    2015-01  2024-12  201501-202412  10m wind speed   m/s
# 1      U10    2025-01  2034-12  202501-203412  10m wind speed   m/s
# 2      U10    2035-01  2044-12  203501-204412  10m wind speed   m/s
# 3      U10    2045-01  2054-12  204501-205412  10m wind speed   m/s
# 4      U10    2055-01  2064-12  205501-206412  10m wind speed   m/s
#
#    vertical_levels frequency  \
# 0              1.0   month_1
# 1              1.0   month_1
# ...

# %%
# check that we only have cmip6, not smbb, data
member_id = list(subset_1.df.experiment.unique())
print(member_id)
# Out:
# ['ssp370']

# %%
# %%time
with dask.config.set(**{'array.slicing.split_large_chunks': True}):
    dsets_1 = subset_1.to_dataset_dict(cdf_kwargs={'chunks': {'time':240}, 'decode_times': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.stream.forcing_variant.variable'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# CPU times: user 6.76 s, sys: 131 ms, total: 6.89 s
# Wall time: 9.06 s

# %%
# load in the future datasets
futures_1 = []
for key in sorted(dsets_1.keys()):
    futures_1.append(dsets_1[key])
    print(key)
# Out:
# atm.ssp370.cam.h0.cmip6.U10

# %%
future_ds_1 = xr.concat(futures_1, dim='member_id')

# %%
future_ds_1.time
# Out:
# <xarray.DataArray 'time' (time: 1032)>
# array([cftime.DatetimeNoLeap(2015, 2, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 3, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2015, 4, 1, 0, 0, 0, 0, has_year_zero=True), ...,
#        cftime.DatetimeNoLeap(2100, 11, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2100, 12, 1, 0, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2101, 1, 1, 0, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2015-02-01 00:00:00 ... 2101-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds

# %%
# Shift months by one to be center of time period.
# Take average of the time bounds to get middle of month
# will lose some attributes with time, so may need to put this back in later...
future_ds_1['time'] = future_ds_1.time_bnds.load().mean(dim='nbnd').sel(member_id='r1i1281p1f1')

# %%
U10_le = future_ds_1[var_in_1]

# %%
U10_le.persist()
# Out:
# <xarray.DataArray 'U10' (member_id: 50, time: 1032, lat: 192, lon: 288)>
# dask.array<concatenate, shape=(50, 1032, 192, 288), dtype=float32, chunksize=(1, 120, 192, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * member_id  (member_id) <U12 'r10i1181p1f1' 'r10i1231p1f1' ... 'r9i1301p1f1'
# Attributes:
#     units:         m/s
#     long_name:     10m wind speed
#     cell_methods:  time: mean

# %%
U10_le.sel(member_id='r1i1281p1f1').isel(time=0).plot()

# %%
U10_le
# Out:
# <xarray.DataArray 'U10' (member_id: 50, time: 1032, lat: 192, lon: 288)>
# dask.array<concatenate, shape=(50, 1032, 192, 288), dtype=float32, chunksize=(1, 120, 192, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * member_id  (member_id) <U12 'r10i1181p1f1' 'r10i1231p1f1' ... 'r9i1301p1f1'
# Attributes:
#     units:         m/s
#     long_name:     10m wind speed
#     cell_methods:  time: mean

# %%
# set mask lat/lon to equal those from LE, otherwise masking below doesn't work properly
my_mask['lat'] = U10_le['lat']
my_mask['lon'] = U10_le['lon']

# %%
#mask just NH ocean points
U10_masked_le = U10_le.where((U10_le['lat']>70.0) & (my_mask<0.5), drop=True)
# Out:
# /glade/work/duvivier/miniconda3/envs/antarctica_som_env/lib/python3.7/site-packages/xarray/core/indexing.py:1226: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
# test simple plot
U10_masked_le.sel(member_id='r1i1281p1f1').isel(time=0).plot()

# %%
U10_masked_le
# Out:
# <xarray.DataArray 'U10' (member_id: 50, time: 1032, lat: 22, lon: 288)>
# dask.array<where, shape=(50, 1032, 22, 288), dtype=float32, chunksize=(1, 120, 22, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * lat        (lat) float64 70.21 71.15 72.09 73.04 ... 87.17 88.12 89.06 90.0
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * member_id  (member_id) <U12 'r10i1181p1f1' 'r10i1231p1f1' ... 'r9i1301p1f1'
# Attributes:
#     units:         m/s
#     long_name:     10m wind speed
#     cell_methods:  time: mean

# %%
#U10_masked_le.persist()
U10_masked_le.load()
# Out:
# <xarray.DataArray 'U10' (member_id: 50, time: 1032, lat: 22, lon: 288)>
# array([[[[10.87047  , 10.828375 , 10.820683 , ..., 11.009366 ,
#           10.995667 , 10.955311 ],
#          [10.520812 , 10.551184 , 10.596888 , ..., 10.772621 ,
#           10.699037 , 10.57545  ],
#          [10.455039 , 10.55242  , 10.607426 , ..., 10.518526 ,
#           10.426251 , 10.392168 ],
#          ...,
#          [ 5.78851  ,  5.778726 ,  5.768209 , ...,  5.810846 ,
#            5.8038464,  5.796437 ],
#          [ 5.7001243,  5.693169 ,  5.6854906, ...,  5.7161965,
#            5.7128196,  5.706865 ],
#          [ 5.5398855,  5.540644 ,  5.541333 , ...,  5.5371037,
#            5.5381265,  5.5390496]],
#
#         [[ 8.922403 ,  9.006664 ,  9.005695 , ...,  8.673686 ,
#            8.762959 ,  8.849436 ],
#          [ 8.648395 ,  8.807054 ,  8.922185 , ...,  8.345491 ,
#            8.382178 ,  8.454087 ],
#          [ 8.337257 ,  8.498895 ,  8.590935 , ...,  8.192364 ,
# ...

# %% [markdown]
# ## Calculate seasonal means

# %%
season_names = ['OND', 'JFM', 'AMJ', 'JAS']

# %%
# calculate seasonal indexes  - DIDN'T END UP DOING IT THIS WAY, DID IT MANUALLY FOR GROUPINGS ABOVE
#season_names = ['DJF', 'MAM', 'JJA', 'SON']
#season_idxs_le = sidragtop_masked_le.groupby('time.season').groups
#season_idxs_rufmod = sidragtop_masked_rufmod.groupby('time.season').groups

# %%
# find total years
xarr_le = U10_masked_le.coords['time.year'][(U10_masked_le.coords['time.month']==1)]
xarr_rufmod = U10_masked_rufmod.coords['time.year'][(U10_masked_rufmod.coords['time.month']==1)]

# %%
# Loop through seasons - rufmod

# make numpy array to fill and specify dimensions we want
seas_array_rufmod = np.zeros([len(season_names),len(xarr_rufmod),len(U10_masked_rufmod.member_id),len(U10_masked_rufmod.lat),len(U10_masked_rufmod.lon)])

for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # get temporary array of just these month by season
    if ss == 'JFM':
        temp1 = U10_masked_rufmod.isel(time=U10_masked_rufmod.time.dt.month.isin([1,2,3]))
    if ss == 'AMJ':
        temp1 = U10_masked_rufmod.isel(time=U10_masked_rufmod.time.dt.month.isin([4,5,6]))
    if ss == 'JAS':
        temp1 = U10_masked_rufmod.isel(time=U10_masked_rufmod.time.dt.month.isin([7,8,9]))
    if ss == 'OND':
        temp1 = U10_masked_rufmod.isel(time=U10_masked_rufmod.time.dt.month.isin([10,11,12]))
    # now loop through years to get the seasonal average by year for each ensemble member
    for yy in xarr_rufmod:
        if yy == 2015:
            y_count = 0
        else: 
            y_count = y_count+1 
        # select only the indexes for this year
        temp2 = temp1.isel(time=temp1.time.dt.year.isin([yy]))
        temp3 = temp2.mean(dim='time')
        seas_array_rufmod[s_count,y_count,:,:,:] = temp3
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
# Loop through seasons - CESM2-LE

# make numpy array to fill and specify dimensions we want
seas_array_le = np.zeros([len(season_names),len(xarr_le),len(U10_masked_le.member_id),len(U10_masked_le.lat),len(U10_masked_le.lon)])

for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # get temporary array of just these month by season
    if ss == 'JFM':
        temp1 = U10_masked_le.isel(time=U10_masked_le.time.dt.month.isin([1,2,3]))
    if ss == 'AMJ':
        temp1 = U10_masked_le.isel(time=U10_masked_le.time.dt.month.isin([4,5,6]))
    if ss == 'JAS':
        temp1 = U10_masked_le.isel(time=U10_masked_le.time.dt.month.isin([7,8,9]))
    if ss == 'OND':
        temp1 = U10_masked_le.isel(time=U10_masked_le.time.dt.month.isin([10,11,12]))
    # now loop through years to get the seasonal average by year for each ensemble member
    for yy in xarr_le:
        if yy == 2015:
            y_count = 0
        else: 
            y_count = y_count+1 
        # select only the indexes for this year
        temp2 = temp1.isel(time=temp1.time.dt.year.isin([yy]))
        temp3 = temp2.mean(dim='time')
        seas_array_le[s_count,y_count,:,:,:] = temp3
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
print(seas_array_le.shape)
print(seas_array_rufmod.shape)
# Out:
# (4, 86, 50, 22, 288)
# (4, 86, 5, 22, 288)

# %%
U10_masked_le
# Out:
# <xarray.DataArray 'U10' (member_id: 50, time: 1032, lat: 22, lon: 288)>
# array([[[[10.87047  , 10.828375 , 10.820683 , ..., 11.009366 ,
#           10.995667 , 10.955311 ],
#          [10.520812 , 10.551184 , 10.596888 , ..., 10.772621 ,
#           10.699037 , 10.57545  ],
#          [10.455039 , 10.55242  , 10.607426 , ..., 10.518526 ,
#           10.426251 , 10.392168 ],
#          ...,
#          [ 5.78851  ,  5.778726 ,  5.768209 , ...,  5.810846 ,
#            5.8038464,  5.796437 ],
#          [ 5.7001243,  5.693169 ,  5.6854906, ...,  5.7161965,
#            5.7128196,  5.706865 ],
#          [ 5.5398855,  5.540644 ,  5.541333 , ...,  5.5371037,
#            5.5381265,  5.5390496]],
#
#         [[ 8.922403 ,  9.006664 ,  9.005695 , ...,  8.673686 ,
#            8.762959 ,  8.849436 ],
#          [ 8.648395 ,  8.807054 ,  8.922185 , ...,  8.345491 ,
#            8.382178 ,  8.454087 ],
#          [ 8.337257 ,  8.498895 ,  8.590935 , ...,  8.192364 ,
# ...

# %%
# convert the numpy array to a xarray for easier plotting
U10_seas_le = xr.DataArray(seas_array_le,dims=('season','time','member_id','lat','lon'))
U10_seas_rufmod = xr.DataArray(seas_array_rufmod,dims=('season','time','member_id','lat','lon'))

# %%
# set coordinate arrays
U10_seas_le['season'] = season_names
U10_seas_le['time'] = xarr_le
U10_seas_le['member_id'] = U10_masked_le['member_id']
U10_seas_le['lat'] = U10_masked_le['lat'].values
U10_seas_le['lon'] = U10_masked_le['lon'].values

U10_seas_rufmod['season'] = season_names
U10_seas_rufmod['time'] = xarr_rufmod
U10_seas_rufmod['member_id'] = U10_masked_rufmod['member_id']
U10_seas_rufmod['lat'] = U10_masked_rufmod['lat'].values
U10_seas_rufmod['lon'] = U10_masked_rufmod['lon'].values

# %% [markdown]
# ## Calculate trends - 2020-2100

# %%
# Set indices for full period - 2020-2100
ind_st = 5
ind_ed = 85

# %%
# define some functions from Liz Maroon
# These allow us to do a linear regression at all points

def pvalue_array(x,y,dname):
    x_an=x-x.mean(dname)
    slope=((x_an)*(y-y.mean(dname))).sum(dname)/((x_an)*(x_an)).sum(dname)
    interc=y.mean(dname)-slope*x.mean(dname)
    ypred=slope*x+interc  
    n=len(x[dname])
    mse=np.sqrt(((y-ypred)**2).sum(dname)/(n-2))
    xsq=np.sqrt(((x_an)**2).sum(dname))
    standerr=mse/xsq
    pval=2*(1-t.cdf(np.abs(slope/standerr),n-2))
    pval=xr.DataArray(pval,dims=standerr.dims,coords=standerr.coords)
    return pval

def rvalue_array(x,y,dname):  
    xmean=x.mean(dname)
    ymean=y.mean(dname)
    numer=(x*y).mean(dname)-xmean*ymean
    denom=np.sqrt(((x**2).mean(dname)-xmean**2)*\
                  (((y**2).mean(dname))-(ymean**2)))
    return numer/denom

def regcoeff_array(x,y,dname):
    x_an=x-x.mean(dname)
    y_an=y-y.mean(dname)
    slope=(x_an*y_an).sum(dname)/(x_an*x_an).sum(dname)
    return slope

# %%
# test this with Liz's functions
# Calculate ensemble means
U10_seas_ens_mean_le = U10_seas_le.mean(dim='member_id')
tseries = xarr_le
# grab first season only
spatial = U10_seas_ens_mean_le[0,:,:,:]
# set time coordinate arrays to be equal
tseries['time'] = spatial.time
# calculate stats
regcoeff=regcoeff_array(tseries,spatial,'time')
rvalues=rvalue_array(tseries,spatial,'time')
pvalues=pvalue_array(tseries,spatial,'time')
# plot return
regcoeff.plot()
#pvalues.plot()

# %% [markdown]
# ## Calculate regression for ensemble mean at each point
#
# * Want array like this: slope_rufmod = 4(nseas)x22(nlat)x288(nlon)
# * Keep slope and pvalues --> Use pvalue for significance (used 99% level in spatial plot)

# %%
# Calculate ensemble means
U10_seas_ens_mean_le = U10_seas_le.mean(dim='member_id')
U10_seas_ens_mean_rufmod = U10_seas_rufmod.mean(dim='member_id')

# %%
U10_seas_ens_mean_rufmod.shape
# Out:
# (4, 86, 22, 288)

# %%
# Calculate trends for ensemble mean by seasons - rufmod

# make numpy array to fill and specify dimensions we want
regcoeff_seas_array_rufmod = np.zeros([len(season_names),len(U10_masked_rufmod.lat),len(U10_masked_rufmod.lon)])
pvalues_seas_array_rufmod = np.zeros([len(season_names),len(U10_masked_rufmod.lat),len(U10_masked_rufmod.lon)])

#for ss in season_names[0:1]:
for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # Grab the time array
    tseries = xarr_rufmod[ind_st:ind_ed]
    # Grab data
    # subset by the years we're interested in
    spatial = U10_seas_ens_mean_rufmod[s_count,ind_st:ind_ed,:,:]
    # set time coordinates to be equal
    tseries['time'] = spatial.time
    # Calculate rufmod regressions
    regcoeff=10*regcoeff_array(tseries,spatial,'time')
    pvalues=pvalue_array(tseries,spatial,'time')
    # put this into a nice array
    regcoeff_seas_array_rufmod[s_count,:,:] = regcoeff
    pvalues_seas_array_rufmod[s_count,:,:] = pvalues
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
# Calculate trends for ensemble mean by seasons - le

# make numpy array to fill and specify dimensions we want
regcoeff_seas_array_le = np.zeros([len(season_names),len(U10_masked_le.lat),len(U10_masked_le.lon)])
pvalues_seas_array_le = np.zeros([len(season_names),len(U10_masked_le.lat),len(U10_masked_le.lon)])

#for ss in season_names[0:1]:
for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # Grab the time array
    tseries = xarr_le[ind_st:ind_ed]
    # Grab data
    # subset by the years we're interested in
    spatial = U10_seas_ens_mean_le[s_count,ind_st:ind_ed,:,:]
    # set time coordinates to be equal
    tseries['time'] = spatial.time
    # Calculate rufmod regressions
    regcoeff=10*regcoeff_array(tseries,spatial,'time')
    pvalues=pvalue_array(tseries,spatial,'time')
    # put this into a nice array
    regcoeff_seas_array_le[s_count,:,:] = regcoeff
    pvalues_seas_array_le[s_count,:,:] = pvalues
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
print(regcoeff_seas_array_le.shape)
print(regcoeff_seas_array_rufmod.shape)
# Out:
# (4, 22, 288)
# (4, 22, 288)

# %%
# convert the numpy array to a xarray for easier plotting
regcoeff_seas_ens_mean_le = xr.DataArray(regcoeff_seas_array_le,dims=('season','lat','lon'))
regcoeff_seas_ens_mean_rufmod = xr.DataArray(regcoeff_seas_array_rufmod,dims=('season','lat','lon'))
pvalues_seas_ens_mean_le = xr.DataArray(pvalues_seas_array_le,dims=('season','lat','lon'))
pvalues_seas_ens_mean_rufmod = xr.DataArray(pvalues_seas_array_rufmod,dims=('season','lat','lon'))

# %%
# set coordinate arrays
regcoeff_seas_ens_mean_le['season'] = season_names
regcoeff_seas_ens_mean_le['lat'] = U10_masked_le['lat'].values
regcoeff_seas_ens_mean_le['lon'] = U10_masked_le['lon'].values

regcoeff_seas_ens_mean_rufmod['season'] = season_names
regcoeff_seas_ens_mean_rufmod['lat'] = U10_masked_rufmod['lat'].values
regcoeff_seas_ens_mean_rufmod['lon'] = U10_masked_rufmod['lon'].values

pvalues_seas_ens_mean_le['season'] = season_names
pvalues_seas_ens_mean_le['lat'] = U10_masked_le['lat'].values
pvalues_seas_ens_mean_le['lon'] = U10_masked_le['lon'].values

pvalues_seas_ens_mean_rufmod['season'] = season_names
pvalues_seas_ens_mean_rufmod['lat'] = U10_masked_rufmod['lat'].values
pvalues_seas_ens_mean_rufmod['lon'] = U10_masked_rufmod['lon'].values

# %%
# stack values to more easily plot 
regcoeff_seas_ens_mean_le = regcoeff_seas_ens_mean_le.stack(all=("lat","lon"))
pvalues_seas_ens_mean_le = pvalues_seas_ens_mean_le.stack(all=("lat","lon"))

regcoeff_seas_ens_mean_rufmod = regcoeff_seas_ens_mean_rufmod.stack(all=("lat","lon"))
pvalues_seas_ens_mean_rufmod = pvalues_seas_ens_mean_rufmod.stack(all=("lat","lon"))

# %%
print(regcoeff_seas_ens_mean_le.shape)
print(regcoeff_seas_ens_mean_rufmod.shape)
print(pvalues_seas_ens_mean_le.shape)
print(pvalues_seas_ens_mean_rufmod.shape)
# Out:
# (4, 6336)
# (4, 6336)
# (4, 6336)
# (4, 6336)

# %%
# transpose values
regcoeff_seas_ens_mean_le = regcoeff_seas_ens_mean_le.transpose()
regcoeff_seas_ens_mean_rufmod = regcoeff_seas_ens_mean_rufmod.transpose()

pvalues_seas_ens_mean_le = pvalues_seas_ens_mean_le.transpose()
pvalues_seas_ens_mean_rufmod = pvalues_seas_ens_mean_rufmod.transpose()

# %%
print(regcoeff_seas_ens_mean_le.shape)
print(regcoeff_seas_ens_mean_rufmod.shape)
print(pvalues_seas_ens_mean_le.shape)
print(pvalues_seas_ens_mean_rufmod.shape)
# Out:
# (6336, 4)
# (6336, 4)
# (6336, 4)
# (6336, 4)

# %% [markdown]
# ## Calculate regression for each ensemble at each point
#
# * Want array like this: slope_rufmod = 4(nseas)x5(nens)x22(nlat)x288(nlon)
# * Keep slope and pvalues --> Use pvalue for significance (used 99% level in spatial plot)

# %%
# Calculate trends for each ensemble member by seasons - rufmod

# make numpy array to fill and specify dimensions we want
regcoeff_seas_array_rufmod = np.zeros([len(season_names),len(U10_masked_rufmod.member_id),len(U10_masked_rufmod.lat),len(U10_masked_rufmod.lon)])
pvalues_seas_array_rufmod = np.zeros([len(season_names),len(U10_masked_rufmod.member_id),len(U10_masked_rufmod.lat),len(U10_masked_rufmod.lon)])

#for ss in season_names[0:1]:
for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # now loop through each ensemble member
    for member_id in U10_seas_rufmod.member_id.values:
        #print(member_id)
        if member_id == 0:
            e_count = 0
        else: 
            e_count = e_count+1
        # Grab the time array
        tseries = xarr_rufmod[ind_st:ind_ed]
        # Grab data
        temp1 = U10_seas_rufmod.sel(member_id=member_id,season=ss)
        # subset by the years we're interested in
        spatial = temp1[ind_st:ind_ed,:,:]
        # set time coordinates to be equal
        tseries['time'] = spatial.time
        # Calculate rufmod regressions
        regcoeff=10*regcoeff_array(tseries,spatial,'time')
        pvalues=pvalue_array(tseries,spatial,'time')
        # put this into a nice array
        regcoeff_seas_array_rufmod[s_count,e_count,:,:] = regcoeff
        pvalues_seas_array_rufmod[s_count,e_count,:,:] = pvalues
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
# Calculate trends for each ensemble member by seasons - CESM2-LE

# make numpy array to fill and specify dimensions we want
regcoeff_seas_array_le = np.zeros([len(season_names),len(U10_masked_le.member_id),len(U10_masked_le.lat),len(U10_masked_le.lon)])
pvalues_seas_array_le = np.zeros([len(season_names),len(U10_masked_le.member_id),len(U10_masked_le.lat),len(U10_masked_le.lon)])

#for ss in season_names[0:1]:
for ss in season_names:
    print(ss)
    if ss == 'OND':
        s_count = 0
    else: 
        s_count = s_count+1
    # now loop through each ensemble member
    for member_id in U10_seas_le.member_id.values:
        #print(member_id)
        if member_id == 'r10i1181p1f1':
            e_count = 0
        else: 
            e_count = e_count+1
        # Grab the time array
        tseries = xarr_le[ind_st:ind_ed]
        # Grab data
        temp1 = U10_seas_le.sel(member_id=member_id,season=ss)
        # subset by the years we're interested in
        spatial = temp1[ind_st:ind_ed,:,:]
        # set time coordinates to be equal
        tseries['time'] = spatial.time
        # Calculate rufmod regressions
        regcoeff=10*regcoeff_array(tseries,spatial,'time')
        pvalues=pvalue_array(tseries,spatial,'time')
        # put this into a nice array
        regcoeff_seas_array_le[s_count,e_count,:,:] = regcoeff
        pvalues_seas_array_le[s_count,e_count,:,:] = pvalues
# Out:
# OND
# JFM
# AMJ
# JAS

# %%
print(regcoeff_seas_array_le.shape)
print(regcoeff_seas_array_rufmod.shape)
# Out:
# (4, 50, 22, 288)
# (4, 5, 22, 288)

# %%
# convert the numpy array to a xarray for easier plotting
regcoeff_seas_le = xr.DataArray(regcoeff_seas_array_le,dims=('season','member_id','lat','lon'))
regcoeff_seas_rufmod = xr.DataArray(regcoeff_seas_array_rufmod,dims=('season','member_id','lat','lon'))
pvalues_seas_le = xr.DataArray(pvalues_seas_array_le,dims=('season','member_id','lat','lon'))
pvalues_seas_rufmod = xr.DataArray(pvalues_seas_array_rufmod,dims=('season','member_id','lat','lon'))

# %%
# set coordinate arrays
regcoeff_seas_le['season'] = season_names
regcoeff_seas_le['member_id'] = U10_masked_le['member_id']
regcoeff_seas_le['lat'] = U10_masked_le['lat'].values
regcoeff_seas_le['lon'] = U10_masked_le['lon'].values

regcoeff_seas_rufmod['season'] = season_names
regcoeff_seas_rufmod['member_id'] = U10_masked_rufmod['member_id']
regcoeff_seas_rufmod['lat'] = U10_masked_rufmod['lat'].values
regcoeff_seas_rufmod['lon'] = U10_masked_rufmod['lon'].values

pvalues_seas_le['season'] = season_names
pvalues_seas_le['member_id'] = U10_masked_le['member_id']
pvalues_seas_le['lat'] = U10_masked_le['lat'].values
pvalues_seas_le['lon'] = U10_masked_le['lon'].values

pvalues_seas_rufmod['season'] = season_names
pvalues_seas_rufmod['member_id'] = U10_masked_rufmod['member_id']
pvalues_seas_rufmod['lat'] = U10_masked_rufmod['lat'].values
pvalues_seas_rufmod['lon'] = U10_masked_rufmod['lon'].values

# %%
print(regcoeff_seas_le.shape)
print(regcoeff_seas_rufmod.shape)
# Out:
# (4, 50, 22, 288)
# (4, 5, 22, 288)

# %%
# stack values to more easily plot 
regcoeff_seas_le = regcoeff_seas_le.stack(all=("member_id","lat","lon"))
pvalues_seas_le = pvalues_seas_le.stack(all=("member_id","lat","lon"))

regcoeff_seas_rufmod = regcoeff_seas_rufmod.stack(all=("member_id","lat","lon"))
pvalues_seas_rufmod = pvalues_seas_rufmod.stack(all=("member_id","lat","lon"))

# %%
print(regcoeff_seas_le.shape)
print(regcoeff_seas_rufmod.shape)
print(pvalues_seas_le.shape)
print(pvalues_seas_rufmod.shape)
# Out:
# (4, 316800)
# (4, 31680)
# (4, 316800)
# (4, 31680)

# %%
# transpose values
regcoeff_seas_le = regcoeff_seas_le.transpose()
regcoeff_seas_rufmod = regcoeff_seas_rufmod.transpose()

pvalues_seas_le = pvalues_seas_le.transpose()
pvalues_seas_rufmod = pvalues_seas_rufmod.transpose()

# %%
print(regcoeff_seas_le.shape)
print(regcoeff_seas_rufmod.shape)
print(pvalues_seas_le.shape)
print(pvalues_seas_rufmod.shape)
# Out:
# (316800, 4)
# (31680, 4)
# (316800, 4)
# (31680, 4)

# %% [markdown]
# ## Plot box and whisker plots
#
# * Mask what goes into the box plot by significance
# * Then plot box and whisker plots by season of the trends at each point

# %%
def setBoxColor(boxplot, colors):

    # Set edge color of the outside and median lines of the boxes
    for element in ['boxes', 'medians']:
        for box, color in zip(boxplot[element], colors):
            plt.setp(box, color=color,linewidth=3)

    # Set the color of the whiskers and caps of the boxes
    for element in ['whiskers', 'caps']:
        for box, color in zip(
                zip(boxplot[element][::2], boxplot[element][1::2]), colors):
            plt.setp(box, color=color,linewidth=3)

# %% [markdown]
# ### Plot both datasets - all trends, even insignificant ones

# %%
# Now make panel plot with both the datasets - all points, even insignificant ones

# create figure
fig = plt.figure(figsize=(20,20))
fout = 'cesm2_le_and_rufmod_'+var_in_1+'_all_trends_2020_2100'
title = 'U10 seasonal trends over sea ice - 2020-2100'

# Make subplots - note it's nrow x ncol x index (starting upper left)
w = 0.1
ax = fig.add_subplot(1,1,1)
# plot boxes
boxplots1 = ax.boxplot(regcoeff_seas_ens_mean_le,labels=(" "," "," "," "),showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.2,2.2,3.2,4.2])
boxplots2 = ax.boxplot(regcoeff_seas_le,labels=(" "," "," "," "),showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.4,2.4,3.4,4.4])
boxplots3 = ax.boxplot(regcoeff_seas_ens_mean_rufmod, labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.6,2.6,3.6,4.6])
boxplots4 = ax.boxplot(regcoeff_seas_rufmod, labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.8,2.8,3.8,4.8])
# set colors for each box
setBoxColor(boxplots1, 4*['black'])
setBoxColor(boxplots2, 4*['grey'])
setBoxColor(boxplots3, 4*['blue'])
setBoxColor(boxplots4, 4*['skyblue'])
# set axis info
plt.axhline(y=0, color='grey', linestyle=':')
plt.axvline(x=2, color='grey', linestyle=':')
plt.axvline(x=3, color='grey', linestyle=':')
plt.axvline(x=4, color='grey', linestyle=':')
plt.xlabel('season',fontsize=15)
#plt.xticks(fontsize=15)
plt.xlim([1,5])
plt.ylabel('(m/s)/decade',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-0.3,0.3])
# add labels manually
plt.title(title,fontsize=20)
plt.text(1.44,-0.35,"OND",fontsize=15,color='black')
plt.text(2.44,-0.35,"JFM",fontsize=15,color='black')
plt.text(3.44,-0.35,"AMJ",fontsize=15,color='black')
plt.text(4.44,-0.35,"JAS",fontsize=15,color='black')
plt.text(4.1, 0.27, "CESM2-LE - ensemble mean", fontsize=15, color='black')
plt.text(4.1, 0.24, "CESM2-LE - ensembles (n=50)", fontsize=15, color='grey')
plt.text(4.1, 0.21, "SMOOTH - ensemble mean", fontsize=15, color='blue')
plt.text(4.1, 0.18, "SMOOTH - ensembles (n=5)", fontsize=15, color='skyblue')
    
# Finalize figure and save
fig.subplots_adjust(bottom=0.45,wspace=0.2)
fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)

# %% [markdown]
# ### Plot both datasets - only significant trends

# %%
# set significance level (0.05 --> 95%; 0.01 --> 99%)
sigval = 0.01

# %%
# create masks of where data is significant
mask_ens_mean_le = ~np.isnan(regcoeff_seas_ens_mean_le.where(pvalues_seas_ens_mean_le < sigval))
mask_ens_mean_rufmod = ~np.isnan(regcoeff_seas_ens_mean_rufmod.where(pvalues_seas_ens_mean_rufmod < sigval))

mask_le = ~np.isnan(regcoeff_seas_le.where(pvalues_seas_le < sigval))
mask_rufmod = ~np.isnan(regcoeff_seas_rufmod.where(pvalues_seas_rufmod < sigval))

# %%
#put the data into lists because the number of significant trends will be different by season and dataset
regcoeff_seas_ens_mean_le_masked = [d[m] for d, m in zip(regcoeff_seas_ens_mean_le.T,mask_ens_mean_le.T)]
regcoeff_seas_ens_mean_rufmod_masked = [d[m] for d, m in zip(regcoeff_seas_ens_mean_rufmod.T,mask_ens_mean_rufmod.T)]

regcoeff_seas_le_masked = [d[m] for d, m in zip(regcoeff_seas_le.T,mask_le.T)]
regcoeff_seas_rufmod_masked = [d[m] for d, m in zip(regcoeff_seas_rufmod.T,mask_rufmod.T)]

# %%
# check the different lengths for seasons
print("number significant points by season for CESM2-LE ensemble mean")
print("OND:"+str(len(regcoeff_seas_ens_mean_le_masked[0])))
print("JFM:"+str(len(regcoeff_seas_ens_mean_le_masked[1])))
print("AMJ:"+str(len(regcoeff_seas_ens_mean_le_masked[2])))
print("JAS:"+str(len(regcoeff_seas_ens_mean_le_masked[3])))
print("number significant points by season for SMOOTH ensemble mean")
print("OND:"+str(len(regcoeff_seas_ens_mean_rufmod_masked[0])))
print("JFM:"+str(len(regcoeff_seas_ens_mean_rufmod_masked[1])))
print("AMJ:"+str(len(regcoeff_seas_ens_mean_rufmod_masked[2])))
print("JAS:"+str(len(regcoeff_seas_ens_mean_rufmod_masked[3])))
print("number significant points by season for CESM2-LE all members")
print("OND:"+str(len(regcoeff_seas_le_masked[0])))
print("JFM:"+str(len(regcoeff_seas_le_masked[1])))
print("AMJ:"+str(len(regcoeff_seas_le_masked[2])))
print("JAS:"+str(len(regcoeff_seas_le_masked[3])))
print("number significant points by season for SMOOTH all members")
print("OND:"+str(len(regcoeff_seas_rufmod_masked[0])))
print("JFM:"+str(len(regcoeff_seas_rufmod_masked[1])))
print("AMJ:"+str(len(regcoeff_seas_rufmod_masked[2])))
print("JAS:"+str(len(regcoeff_seas_rufmod_masked[3])))
# Out:
# number significant points by season for CESM2-LE ensemble mean
# OND:5092
# JFM:5086
# AMJ:2143
# JAS:4456
# number significant points by season for SMOOTH ensemble mean
# OND:4775
# JFM:3942
# AMJ:755
# JAS:1825
# number significant points by season for CESM2-LE all members
# OND:216647
# JFM:115525
# AMJ:8169
# JAS:49316
# number significant points by season for SMOOTH all members
# OND:17537
# JFM:9352
# AMJ:1992
# JAS:2477

# %%
# Now make panel plot with both the datasets - all points, even insignificant ones

# create figure
fig = plt.figure(figsize=(20,20))
fout = 'cesm2_le_and_rufmod_'+var_in_1+'_sig0.01_trends_2020_2100'
title = 'U10 seasonal trends over sea ice - 2020-2100'

# Make subplots - note it's nrow x ncol x index (starting upper left)
w = 0.1
ax = fig.add_subplot(1,1,1)
# plot boxes
boxplots1 = ax.boxplot(regcoeff_seas_ens_mean_le_masked,labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.2,2.2,3.2,4.2])
boxplots2 = ax.boxplot(regcoeff_seas_le_masked,labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.4,2.4,3.4,4.4])
boxplots3 = ax.boxplot(regcoeff_seas_ens_mean_rufmod_masked, labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.6,2.6,3.6,4.6])
boxplots4 = ax.boxplot(regcoeff_seas_rufmod_masked, labels=(" "," "," "," "), showfliers=False, autorange=False, widths=[w, w, w, w], positions=[1.8,2.8,3.8,4.8])
# set colors for each box
setBoxColor(boxplots1, 4*['black'])
setBoxColor(boxplots2, 4*['grey'])
setBoxColor(boxplots3, 4*['blue'])
setBoxColor(boxplots4, 4*['skyblue'])
# set axis info
plt.axhline(y=0, color='grey', linestyle=':')
plt.axvline(x=2, color='grey', linestyle=':')
plt.axvline(x=3, color='grey', linestyle=':')
plt.axvline(x=4, color='grey', linestyle=':')
#plt.xlabel('season',fontsize=15)
#plt.xticks(fontsize=15)
plt.xlim([1,5])
plt.ylabel('(m/s)/decade',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([-0.2,0.3])
# add labels manually
plt.title(title,fontsize=20)
plt.text(1.44,-0.23,"OND",fontsize=15,color='black')
plt.text(2.44,-0.23,"JFM",fontsize=15,color='black')
plt.text(3.44,-0.23,"AMJ",fontsize=15,color='black')
plt.text(4.44,-0.23,"JAS",fontsize=15,color='black')
plt.text(4.05, 0.27, "CESM2-LE - ensemble mean", fontsize=15, weight=1000, color='black')
plt.text(4.05, 0.24, "CESM2-LE - ensembles (n=50)", fontsize=15, weight=1000, color='grey')
plt.text(4.05, 0.21, "SMOOTH - ensemble mean", fontsize=15, weight=1000, color='blue')
plt.text(4.05, 0.18, "SMOOTH - ensembles (n=5)", fontsize=15, weight=1000, color='skyblue')
    
# Finalize figure and save
fig.subplots_adjust(bottom=0.45,wspace=0.2)
fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
