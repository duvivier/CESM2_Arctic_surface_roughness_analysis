# %% [markdown]
# # Plot seasonal zonal mean winds at set pressure levels
#
# * **Description**: Reads in and creates plots of wind at some level
# * **Input data**: CESM2-LE and Rufmod processed vertical files
# * **Output data**: PNG figures of trends
# * **Creator**: Alice DuVivier
# * **Date**: March 2022

# %% [markdown]
# The rufmod experiments were performed where the sea ice roughness over Arctic sea ice regions was set to be equal to what it would be over open ocean. This is to better understand ice-atmosphere coupling, processes, and feedbacks.

# %%
import xarray as xr
import numpy as np
from datetime import timedelta
import glob

import pop_tools

import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.gridspec import GridSpec

import geocat.datafiles as gdf
import geocat.viz.util as gvutil
from geocat.viz import cmaps as gvcmaps
import geocat.comp as gcomp

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from scipy.stats import linregress,pearsonr, t

# %% [markdown]
# ## Load in files

# %%
data_dir = '/glade/p/cgd/ppc/duvivier/cesm2_arctic_cyclones/rufmod_analysis/version_3/wind_vertical/'

# %%
ds_le = xr.open_mfdataset(data_dir+'CESM2-LE_vertical_seas_ens_mean_vert_WS.nc')
ds_rufmod = xr.open_mfdataset(data_dir+'rufmod_vertical_seas_ens_mean_vert_WS.nc')

# %%
ws_le = ds_le['vert_ws']
ws_rufmod = ds_rufmod['vert_ws']

# %%
# set coordinates to be equal so we don't get weirdness when calculating
ws_rufmod['lat'] = ws_le.lat
ws_rufmod['lon'] = ws_le.lon

# %%
# find total years
xarr_le = ws_le.time
xarr_rufmod = ws_rufmod.time

# %%
# set season names
season_names = ['OND','JFM', 'AMJ', 'JAS']

# %%
# set pressure levels to be hPa instead of Pa
ws_le['plev'] = ws_le.plev.values/100.0
ws_rufmod['plev'] = ws_rufmod.plev.values/100.0

# %%
ws_le.plev
# Out:
# <xarray.DataArray 'plev' (plev: 17)>
# array([1000.,  975.,  950.,  925.,  900.,  875.,  850.,  825.,  800.,  775.,
#         750.,  700.,  600.,  500.,  400.,  300.,  200.])
# Coordinates:
#   * plev     (plev) float64 1e+03 975.0 950.0 925.0 ... 500.0 400.0 300.0 200.0

# %% [markdown]
# ## Calculate zonal means

# %%
ws_le_zonal = ws_le.mean(dim='lon')
ws_rufmod_zonal = ws_rufmod.mean(dim='lon')

# %%
ws_le_zonal.sel(season='OND',time=2020).plot()

# %% [markdown]
# ## Make Hovemoller-like plots at given pressure level by season

# %%
# set subset of pressure level
plev_sub = [1000, 925, 850, 700, 500]

# %%
# set units
units = '(m/s)'

#Plot each season and percent difference
vmax_in = 7
vmin_in = 0
cmap_in = plt.cm.get_cmap('viridis')
vmax_diff = 50
vmin_diff = -50
cmap_diff = plt.cm.get_cmap('bwr')

for s_count, ss in enumerate(season_names):
    print('Plotting regressions for '+ss)
    for pp in plev_sub:
        print('Pressure levels '+str(pp)+'hPa')
    
        # Grab data
        data_le = ws_le_zonal.sel(season=ss,plev=pp)
        data_rufmod = ws_rufmod_zonal.sel(season=ss,plev=pp)
        diff = 100*((data_rufmod - data_le)/data_le)
        
        # mask differences that are less than 10%
        diff = diff.where(abs(diff) > 10.0)
            
        # create figure
        fig = plt.figure(figsize=(20,10))
        fout = 'cesm2_le_and_rufmod_mean_wind_speed_2020_2100_'+ss+'_'+str(pp)+'hPa'
        title = ss+' zonal mean wind speed - 2020-2100 - at '+str(pp)+'hPa'

        # Make subplots - note it's nrow x ncol x index (starting upper left)
        # First subplot: CESM2-LE
        ax = fig.add_subplot(1,3,1)
        this=ax.pcolor(data_le.lat,data_le.time,data_le,
                       cmap=cmap_in,vmin=vmin_in,vmax=vmax_in)
        # colorbar stuff
        cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04)
        cbar.ax.tick_params(labelsize=15, labelrotation=45)
        cbar.ax.set_xlabel(units+'/decade', fontsize=15)
        # axis limits and name stuff
        plt.xlabel('Latitude',fontsize=15)
        plt.xticks(fontsize=15)
        plt.ylabel('year',fontsize=15)
        plt.yticks(fontsize=15)
        #plt.ylim([500,1000])
        #ax.set_ylim(ax.get_ylim()[::-1])
        plt.title('CESM2-LE',fontsize=20)
    
        # Second subplot: SMOOTH
        ax = fig.add_subplot(1,3,2)
        this=ax.pcolor(data_rufmod.lat,data_rufmod.time,data_rufmod,
                       cmap=cmap_in,vmin=vmin_in,vmax=vmax_in)
        # colorbar stuff
        cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04)
        cbar.ax.tick_params(labelsize=15, labelrotation=45)
        cbar.ax.set_xlabel(units+'/decade', fontsize=15)
        # axis limits and name stuff
        plt.xlabel('Latitude',fontsize=15)
        plt.xticks(fontsize=15)
        #plt.xlim([2020,2100])
        plt.ylabel('year',fontsize=15)
        plt.yticks(fontsize=15)
        #plt.ylim([500,1000])
        #ax.set_ylim(ax.get_ylim()[::-1])
        plt.title('SMOOTH',fontsize=20)

        # Third subplot: Diff
        ax = fig.add_subplot(1,3,3)
        this=ax.pcolor(diff.lat,diff.time,diff,
                       cmap=cmap_diff,vmin=vmin_diff,vmax=vmax_diff)
        # colorbar stuff
        cbar = plt.colorbar(this,orientation='horizontal',fraction=0.04)
        cbar.ax.tick_params(labelsize=15, labelrotation=45)
        cbar.ax.set_xlabel('% Difference', fontsize=15)
        # axis limits and name stuff
        plt.xlabel('Latitude',fontsize=15)
        plt.xticks(fontsize=15)
        #plt.xlim([2020,2100])
        plt.ylabel('year',fontsize=15)
        plt.yticks(fontsize=15)
        #plt.ylim([500,1000])
        #ax.set_ylim(ax.get_ylim()[::-1])
        plt.title('% Difference from CESM2-LE',fontsize=20)
    
        # Finalize figure and save
        fig.suptitle(title,fontsize=15, y=0.95)  
        fig.subplots_adjust(bottom=0.45,wspace=0.25)
        fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
# Out:
# Plotting regressions for OND
# Pressure levels 1000hPa
# Pressure levels 925hPa
# Pressure levels 850hPa
# Pressure levels 700hPa
# Pressure levels 500hPa
# Plotting regressions for JFM
# Pressure levels 1000hPa
# Pressure levels 925hPa
# Pressure levels 850hPa
# Pressure levels 700hPa
# Pressure levels 500hPa
# Plotting regressions for AMJ
# Pressure levels 1000hPa
# Pressure levels 925hPa
# Pressure levels 850hPa
# Pressure levels 700hPa
# Pressure levels 500hPa
# Plotting regressions for JAS
# Pressure levels 1000hPa
# Pressure levels 925hPa
# Pressure levels 850hPa
# Pressure levels 700hPa
# Pressure levels 500hPa
