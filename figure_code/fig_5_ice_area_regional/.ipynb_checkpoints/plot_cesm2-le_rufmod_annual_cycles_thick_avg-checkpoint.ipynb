# %% [markdown]
# # Plotting decadal annual cycles of Arctic Regional ice state
#
# * **Description**: Plots historical and future annual cycles by decade and region
# * **Input data**: Processed rufmod and cesm2-le regional total netcdf files
# * **Output data**: Annual cycle plots in png format
# * **Creator**: Alice DuVivier
# * **Date**: April 2022

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pop_tools
from datetime import timedelta
import glob
import dask
from matplotlib.gridspec import GridSpec
import pandas as pd
from scipy.stats import ttest_ind

# %% [markdown]
# ## Read in the processed data
#
# This reads in pre-processed regional total ice area or volume for the Arctic.
#
# Total Ice area = sum over lat/lon of (aice*tarea). Units = km2
#
# Ice volume = sum over lat/lon of (hi*tarea). Units = km3

# %%
# list the variables to load
var_in = 'aice'

# aice, hi

# %%
# set base directory where all data live
data_dir = '/glade/p/cgd/ppc/duvivier/cesm2_arctic_cyclones/rufmod_analysis/version_4/ice_state_regional/'

# set file names
fin_le = 'CESM2-LE_all_transient_regional_avg_'+var_in
fin_rufmod = 'rufmod_all_transient_regional_avg_'+var_in

# %%
ds_le = xr.open_dataset(data_dir+fin_le+'.nc',decode_times=True)
ds_rufmod = xr.open_dataset(data_dir+fin_rufmod+'.nc',decode_times=True)

# %%
# double check that year/month is not shifted incorrectly
ds_le.coords['time.month']
ds_rufmod.coords['time.month']
# Out:
# <xarray.DataArray 'month' (time: 1032)>
# array([ 1,  2,  3, ..., 10, 11, 12])
# Coordinates:
#   * time     (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00

# %%
# check what regions we have totals for
ds_le.region

# should match...
mask_in = ['nh_mask', 'Lab_mask', 'GIN_mask', 'Bar_mask', 'ArcOc_mask', 'Sib_mask', 'Beau_mask', 'Bering_mask', 'Hudson_mask', 'CAArch_mask', 'Okhotsk_mask']

# %%
print(ds_le.units)
print(ds_le.longname)

total_le = ds_le['regional_totals']
total_rufmod = ds_rufmod['regional_totals']
# Out:
# km^2
# regional total ice area

# %%
total_le
# Out:
# <xarray.DataArray 'regional_totals' (member_id: 50, time: 1032, region: 14)>
# [722400 values with dtype=float64]
# Coordinates:
#   * time       (time) object 2015-01-16 12:00:00 ... 2100-12-16 12:00:00
#   * member_id  (member_id) object 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * region     (region) object 'nh_mask' 'Lab_mask' ... 'CanCoast_mask'

# %%
data_le = total_le
data_rufmod = total_rufmod

# %% [markdown]
# ### Calculate the monthly means by decade

# %%
# make lists of both the months and decades we'll use
decades = list(range(2010,2100,10))
months = list(range(1,13,1))

# %%
#specify some arrays that will become coordinate arrays
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
decade_names = ['2010','2020','2030','2040','2050','2060','2070','2080','2090']

# %% [markdown]
# #### CESM2-LE calculations

# %%
# For CESM2-LE: loop through months and decades to get all the annual cycles

# make numpy array to fill and specify dimensions we want
array_le = np.zeros([len(total_le.member_id),len(months),len(decades),len(total_le.region)])
#array_le.shape

# decade loop
for dec in decades:
    print('Calculating monthly means for '+str(dec))
    # need to specify which spot in the array we'll fill for the decade
    if dec == 2010:
        count = 0
    else: 
        count = count+1
    # set the start and end years for this decade
    yy_st = dec
    yy_ed = yy_st + 10
    yy = list(range(yy_st,yy_ed,1))
    # subset the data for these years only but keep all months
    temp = data_le.isel(time=data_le.time.dt.year.isin([yy]))
    
    # month loop
    for mm in months:
        #print('Finding month '+str(mm))
        temp2 = temp.isel(time=temp.time.dt.month.isin([mm]))
        array_le[:,(mm-1),count,:] = temp2.mean(dim='time')
# Out:
# Calculating monthly means for 2010
# Calculating monthly means for 2020
# Calculating monthly means for 2030
# Calculating monthly means for 2040
# Calculating monthly means for 2050
# Calculating monthly means for 2060
# Calculating monthly means for 2070
# Calculating monthly means for 2080
# Calculating monthly means for 2090

# %%
# check the shape
print(array_le.shape)
# Out:
# (50, 12, 9, 14)

# %%
# convert the numpy array to a xarray
decadal_means_le = xr.DataArray(array_le,dims=('member_id','month','decade','region'))

# %%
# assign some coordinate arrays
decadal_means_le['member_id'] = total_le.member_id
decadal_means_le['decade'] = np.array(decades)
decadal_means_le['month'] = np.array(months)
decadal_means_le['region'] = total_le.region

# %%
decadal_means_le.decade
# Out:
# <xarray.DataArray 'decade' (decade: 9)>
# array([2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090])
# Coordinates:
#   * decade   (decade) int64 2010 2020 2030 2040 2050 2060 2070 2080 2090

# %% [markdown]
# #### Rufmod experiments

# %%
# For Rufmod: loop through months and decades to get all the annual cycles
# NOTE that we had to change the loop for decades to only do 1950 onward as there isn't data before then for this expt.

# make numpy array to fill and specify dimensions we want
array_rufmod = np.zeros([len(total_rufmod.member_id),len(months),len(decades),len(total_rufmod.region)])
#array_le.shape

# decade loop
for dec in decades:
    print('Calculating monthly means for '+str(dec))
    # need to specify which spot in the array we'll fill for the decade
    if dec == 2010:
        count = 0
    else: 
        count = count+1
    # set the start and end years for this decade
    yy_st = dec
    yy_ed = yy_st + 10
    yy = list(range(yy_st,yy_ed,1))
    # subset the data for these years only but keep all months
    temp = data_rufmod.isel(time=data_rufmod.time.dt.year.isin([yy]))
    
    # month loop
    for mm in months:
        #print('Finding month '+str(mm))
        temp2 = temp.isel(time=temp.time.dt.month.isin([mm]))
        array_rufmod[:,(mm-1),count,:] = temp2.mean(dim='time')
# Out:
# Calculating monthly means for 2010
# Calculating monthly means for 2020
# Calculating monthly means for 2030
# Calculating monthly means for 2040
# Calculating monthly means for 2050
# Calculating monthly means for 2060
# Calculating monthly means for 2070
# Calculating monthly means for 2080
# Calculating monthly means for 2090

# %%
# check the shape
print(array_rufmod.shape)
# Out:
# (5, 12, 9, 14)

# %%
# convert the numpy array to a xarray
decadal_means_rufmod = xr.DataArray(array_rufmod,dims=('member_id','month','decade','region'))

# %%
# assign some coordinate arrays
decadal_means_rufmod['member_id'] = total_rufmod.member_id
decadal_means_rufmod['decade'] = np.array(decades)
decadal_means_rufmod['month'] = np.array(months)
decadal_means_rufmod['region'] = total_rufmod.region

# %%
decadal_means_rufmod.region
# Out:
# <xarray.DataArray 'region' (region: 14)>
# array(['nh_mask', 'Lab_mask', 'GIN_mask', 'Bar_mask', 'ArcOc_mask', 'Sib_mask',
#        'Beau_mask', 'Bering_mask', 'Hudson_mask', 'CAArch_mask',
#        'Okhotsk_mask', 'ArcOc_mask_and_Bar_mask', 'CanBeau_mask',
#        'CanCoast_mask'], dtype=object)
# Coordinates:
#   * region   (region) object 'nh_mask' 'Lab_mask' ... 'CanCoast_mask'

# %% [markdown]
# ## Grab by decade and get differences

# %%
#set some labeling info for plots
if var_in == 'aice':
    # convert to 1000000's of km3
    decadal_means_le = decadal_means_le/(1000000.0)
    decadal_means_rufmod = decadal_means_rufmod/(1000000.0)
else:
    # convert to 1000's of km3
    decadal_means_le = decadal_means_le/(1000.0)
    decadal_means_rufmod = decadal_means_rufmod/(1000.0)

# %%
# calculate means and statistical significance by decades
sigval1 = 0.05

# %%
## Could loop through, but won't for legacy reasons...

# %%
dec = 2020
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2020 = temp1.mean(dim='member_id')
rufmod_data_2020 = temp2.mean(dim='member_id')
# data that's significant
le_data_2020_sig1 = le_data_2020.where(pval <= sigval1)
rufmod_data_2020_sig1 = rufmod_data_2020.where(pval <= sigval1)
# get differences
diff_2020 = rufmod_data_2020 - le_data_2020
pcnt_diff_2020 = 100*((rufmod_data_2020 - le_data_2020)/le_data_2020)
diff_2020_sig1 = diff_2020.where(pval <= sigval1)
pcnt_diff_2020_sig1 = pcnt_diff_2020.where(pval <= sigval1)

# %%
dec = 2030
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2030 = temp1.mean(dim='member_id')
rufmod_data_2030 = temp2.mean(dim='member_id')
# data that's significant
le_data_2030_sig1 = le_data_2030.where(pval <= sigval1)
rufmod_data_2030_sig1 = rufmod_data_2030.where(pval <= sigval1)
# get differences
diff_2030 = rufmod_data_2030 - le_data_2030
pcnt_diff_2030 = 100*((rufmod_data_2030 - le_data_2030)/le_data_2030)
diff_2030_sig1 = diff_2030.where(pval <= sigval1)
pcnt_diff_2030_sig1 = pcnt_diff_2030.where(pval <= sigval1)

# %%
dec = 2040
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2040 = temp1.mean(dim='member_id')
rufmod_data_2040 = temp2.mean(dim='member_id')
# data that's significant
le_data_2040_sig1 = le_data_2040.where(pval <= sigval1)
rufmod_data_2040_sig1 = rufmod_data_2040.where(pval <= sigval1)
# get differences
diff_2040 = rufmod_data_2040 - le_data_2040
pcnt_diff_2040 = 100*((rufmod_data_2040 - le_data_2040)/le_data_2040)
diff_2040_sig1 = diff_2040.where(pval <= sigval1)
pcnt_diff_2040_sig1 = pcnt_diff_2040.where(pval <= sigval1)

# %%
dec = 2050
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2050 = temp1.mean(dim='member_id')
rufmod_data_2050 = temp2.mean(dim='member_id')
# data that's significant
le_data_2050_sig1 = le_data_2050.where(pval <= sigval1)
rufmod_data_2050_sig1 = rufmod_data_2050.where(pval <= sigval1)
# get differences
diff_2050 = rufmod_data_2050 - le_data_2050
pcnt_diff_2050 = 100*((rufmod_data_2050 - le_data_2050)/le_data_2050)
diff_2050_sig1 = diff_2050.where(pval <= sigval1)
pcnt_diff_2050_sig1 = pcnt_diff_2050.where(pval <= sigval1)

# %%
dec = 2060
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2060 = temp1.mean(dim='member_id')
rufmod_data_2060 = temp2.mean(dim='member_id')
# data that's significant
le_data_2060_sig1 = le_data_2060.where(pval <= sigval1)
rufmod_data_2060_sig1 = rufmod_data_2060.where(pval <= sigval1)
# get differences
diff_2060 = rufmod_data_2060 - le_data_2060
pcnt_diff_2060 = 100*((rufmod_data_2060 - le_data_2060)/le_data_2060)
diff_2060_sig1 = diff_2060.where(pval <= sigval1)
pcnt_diff_2060_sig1 = pcnt_diff_2060.where(pval <= sigval1)

# %%
dec = 2070
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2070 = temp1.mean(dim='member_id')
rufmod_data_2070 = temp2.mean(dim='member_id')
# data that's significant
le_data_2070_sig1 = le_data_2070.where(pval <= sigval1)
rufmod_data_2070_sig1 = rufmod_data_2070.where(pval <= sigval1)
# get differences
diff_2070 = rufmod_data_2070 - le_data_2070
pcnt_diff_2070 = 100*((rufmod_data_2070 - le_data_2070)/le_data_2070)
diff_2070_sig1 = diff_2070.where(pval <= sigval1)
pcnt_diff_2070_sig1 = pcnt_diff_2070.where(pval <= sigval1)

# %%
dec = 2080
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2080 = temp1.mean(dim='member_id')
rufmod_data_2080 = temp2.mean(dim='member_id')
# data that's significant
le_data_2080_sig1 = le_data_2080.where(pval <= sigval1)
rufmod_data_2080_sig1 = rufmod_data_2080.where(pval <= sigval1)
# get differences
diff_2080 = rufmod_data_2080 - le_data_2080
pcnt_diff_2080 = 100*((rufmod_data_2080 - le_data_2080)/le_data_2080)
diff_2080_sig1 = diff_2080.where(pval <= sigval1)
pcnt_diff_2080_sig1 = pcnt_diff_2080.where(pval <= sigval1)

# %%
dec = 2090
temp1 = decadal_means_le.sel(decade=dec)
temp2 = decadal_means_rufmod.sel(decade=dec)
tval,pval = ttest_ind(temp1,temp2,axis=0,equal_var=False)
# data to plot
le_data_2090 = temp1.mean(dim='member_id')
rufmod_data_2090 = temp2.mean(dim='member_id')
# data that's significant
le_data_2090_sig1 = le_data_2090.where(pval <= sigval1)
rufmod_data_2090_sig1 = rufmod_data_2090.where(pval <= sigval1)
# get differences
diff_2090 = rufmod_data_2090 - le_data_2090
pcnt_diff_2090 = 100*((rufmod_data_2090 - le_data_2090)/le_data_2090)
diff_2090_sig1 = diff_2090.where(pval <= sigval1)
pcnt_diff_2090_sig1 = pcnt_diff_2090.where(pval <= sigval1)

# %% [markdown]
# ### Plotting!

# %%
mask_sub = ['ArcOc_mask_and_Bar_mask', 'Sib_mask', 'CanBeau_mask', 'CanCoast_mask']

# %%
#set some labeling info for plots
if var_in == 'aice':
    out_tag = 'ice_area'
    label = 'Ice Area'
    units = '($10^{6}$ $km^{2}$)'
else:
    out_tag = 'ice_vol'
    label = 'Ice Volume'
    units = '($10^{3}$ $km^{3}$)'

# %%
# set x arrays against which to plot
xarr = months

# %%
# Plot selected regional ice area with select decades
for reg in mask_sub:
    print('Plotting decadal annual cycles for region '+reg)
    # create figure
    fig = plt.figure(figsize=(40,10))
    fout = 'total_cesm2-le_and_rufmod_'+out_tag+'_'+reg+'_annual_cycle_transient'
    
    # CESM2-LE
    ax = fig.add_subplot(1,4,1)
    # Plot data all
    ax.plot(xarr,le_data_2020.sel(region=reg),label="2020's",color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2030.sel(region=reg),label="2030's",color='indigo',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2040.sel(region=reg),label="2040's",color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2050.sel(region=reg),label="2050's",color='blue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2060.sel(region=reg),label="2060's",color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2070.sel(region=reg),label="2070's",color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2080.sel(region=reg),label="2080's",color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,le_data_2090.sel(region=reg),label="2090's",color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    # Plot the significant differences (95%) as bigger marker
    ax.plot(xarr,le_data_2020_sig1.sel(region=reg),color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2030_sig1.sel(region=reg),color='indigo',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2040_sig1.sel(region=reg),color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2050_sig1.sel(region=reg),color='blue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2060_sig1.sel(region=reg),color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2070_sig1.sel(region=reg),color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2080_sig1.sel(region=reg),color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,le_data_2090_sig1.sel(region=reg),color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    # set some labeling info
    plt.title('CESM2-LE Annual Cycle',fontsize=20)
    plt.xlabel('Month',fontsize=20)
    plt.xticks(xarr,fontsize=20)
    plt.xlim([0.5,12.5])
    plt.ylabel(units,fontsize=20)
    plt.yticks(fontsize=20)
    plt.legend(ncol=1,loc=3,fontsize=15)

    # Diff: SMOOTH-CESM2-LE
    ax = fig.add_subplot(1,4,2)
    # Plot data all
    ax.plot(xarr,diff_2020.sel(region=reg),label="2020's",color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2030.sel(region=reg),label="2030's",color='indigo',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2040.sel(region=reg),label="2040's",color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2050.sel(region=reg),label="2050's",color='blue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2060.sel(region=reg),label="2060's",color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2070.sel(region=reg),label="2070's",color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2080.sel(region=reg),label="2080's",color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,diff_2090.sel(region=reg),label="2090's",color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    # Plot the significant differences (95%) as bigger marker
    ax.plot(xarr,diff_2020_sig1.sel(region=reg),color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2030_sig1.sel(region=reg),color='indigo',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2040_sig1.sel(region=reg),color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2050_sig1.sel(region=reg),color='blue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2060_sig1.sel(region=reg),color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2070_sig1.sel(region=reg),color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2080_sig1.sel(region=reg),color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,diff_2090_sig1.sel(region=reg),color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    # set some labeling info
    plt.title('Diff: SMOOTH - CESM2-LE',fontsize=20)
    plt.xlabel('Month',fontsize=20)
    plt.xticks(xarr,fontsize=20)
    plt.xlim([0.5,12.5])
    plt.ylabel(units,fontsize=20)
    plt.yticks(fontsize=20)
    plt.axhline(y=0, color='grey', linestyle='-', linewidth=0.5)
    #plt.legend(ncol=1,loc=3,fontsize=15)

    # % Diff: SMOOTH-CESM2-LE
    ax = fig.add_subplot(1,4,3)
    # Plot data all
    ax.plot(xarr,pcnt_diff_2020.sel(region=reg),label="2020's",color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2030.sel(region=reg),label="2030's",color='indigo',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2040.sel(region=reg),label="2040's",color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2050.sel(region=reg),label="2050's",color='blue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2060.sel(region=reg),label="2060's",color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2070.sel(region=reg),label="2070's",color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2080.sel(region=reg),label="2080's",color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    ax.plot(xarr,pcnt_diff_2090.sel(region=reg),label="2090's",color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=5)
    # Plot the significant differences (95%) as bigger marker
    ax.plot(xarr,pcnt_diff_2020_sig1.sel(region=reg),color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2030_sig1.sel(region=reg),color='indigo',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2040_sig1.sel(region=reg),color='darkblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2050_sig1.sel(region=reg),color='blue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2060_sig1.sel(region=reg),color='royalblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2070_sig1.sel(region=reg),color='dodgerblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2080_sig1.sel(region=reg),color='deepskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    ax.plot(xarr,pcnt_diff_2090_sig1.sel(region=reg),color='lightskyblue',linestyle='-', linewidth=3, marker='o', markersize=10)
    # set some labeling info
    plt.title('% Difference from CESM2-LE',fontsize=20)
    plt.xlabel('Month',fontsize=20)
    plt.xticks(xarr,fontsize=20)
    plt.xlim([0.5,12.5])
    plt.ylabel(units,fontsize=20)
    plt.yticks(fontsize=20)
    plt.axhline(y=0, color='grey', linestyle='-', linewidth=0.5)
    #plt.legend(ncol=1,loc=3,fontsize=15)
    
    # % Diff: SMOOTH-CESM2-LE
    ax = fig.add_subplot(1,4,4)
    # Plot data all
    ax.plot(xarr,pcnt_diff_2020.sel(region=reg),label="2020's",color='blueviolet',linestyle='-', linewidth=3, marker='o', markersize=5)
    # set some labeling info
    plt.title('empty',fontsize=20)

    # Finalize figure and save
    fig.suptitle(label+' Monthly Ensemble Mean by Decade',fontsize=20, y=0.95)  
    fig.subplots_adjust(hspace=0.3)
    fig = plt.savefig(fout+'.png', bbox_inches='tight', dpi=200)
# Out:
# Plotting decadal annual cycles for region ArcOc_mask_and_Bar_mask
# Plotting decadal annual cycles for region Sib_mask
# Plotting decadal annual cycles for region CanBeau_mask
# Plotting decadal annual cycles for region CanCoast_mask
